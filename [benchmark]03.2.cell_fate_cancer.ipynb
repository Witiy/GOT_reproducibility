# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import scanpy as sc
import torch
from tqdm import tqdm
import torchdiffeq
import pygot
import pandas as pd
import wot
import cospar as cs
import seaborn as sns
import pandas as pd
from pygot.external import TIGON_interface
from help_function import cell_fate_helper as hf
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# %matplotlib inline

# %%
import random
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.cuda.manual_seed(seed)
 
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Preprocess

# %%
adata = sc.read('../pygot_data/03_cellfate/Oren_2021_Nature.h5ad')

# %%
adata.layers['counts'] = adata.X.copy()

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=3000, flavor='cell_ranger')

# %%
adata.raw = adata
adata = adata[:, adata.var.highly_variable]

# %%
sc.tl.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color='celltype')

# %%
sc.tl.paga(adata, groups="celltype")
sc.pl.paga(adata, threshold=0.03, show=False)
# Out:
# <Axes: >

# %%
sc.tl.draw_graph(adata, init_pos="paga")
sc.pl.draw_graph(
    adata, color=["celltype"], legend_loc="on data"
)

# %%
from scipy.sparse import csr_matrix
import numpy as np
clone_key = 'lineage_barcode'
adata.obs[clone_key] = adata.obs[clone_key].astype(str)
#clone_library = adata.obs[clone_key][~np.isnan(adata.obs[clone_key])].unique()
clone_library = adata.obs[clone_key][adata.obs[clone_key] != 'nan'].unique()
X_clone = np.zeros(shape=(len(adata), len(clone_library)))
for i in range(len(clone_library)):
    X_clone[np.where(adata.obs[clone_key] == clone_library[i])[0], i] = 1
X_clone = csr_matrix(X_clone)
adata.obsm['X_clone'] = X_clone

# %%
adata.obs['stage_numeric'] = adata.obs['time_point'].replace(dict(zip(np.sort(np.unique(adata.obs['time_point'])), range(len(adata.obs['time_point'].unique())))))
adata.obs['time_info'] = adata.obs['stage_numeric']
adata.obs['state_info'] = adata.obs['celltype']
adata.obsm['X_emb'] = adata.obsm['X_umap']
sc.write('../pygot_data/03_cellfate/Oren/adata.h5ad', adata)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 56419 × 3000
#     obs: 'nCount_RNA', 'nFeature_RNA', 'nGene', 'nUMI', 'percent.mito', 'sample_id', 'time_point', 'sample_name', 'sample_type', 'full_cell_barcode', 'lineage_barcode', 'clone_size', 'nCount_SCT', 'nFeature_SCT', 'celltype', 'barcodes', 'barcode1', 'barcodes_multi', 'stage_numeric', 'time_info', 'state_info', 'pull', 'pull_high', 'pull_low', 'moscot_fate_bias', 'transition', 'idx', 'got_fate_bias'
#     var: 'name', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'celltype_sizes', 'clonal_time_points', 'data_des', 'draw_graph', 'hvg', 'log1p', 'moscot_results', 'neighbors', 'paga', 'pca', 'state_info_colors', 'time_ordering', 'umap'
#     obsm: 'X_clone', 'X_draw_graph_fa', 'X_emb', 'X_pca', 'X_umap', 'velocity_pca', 'descendant', 'ancestor'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs['cell_state'] = 'Others'
adata.obs.loc[adata.obs.celltype == '14_low', 'cell_state'] = 'Cycling'
adata.obs.loc[adata.obs.celltype == '14_high', 'cell_state'] = 'Non-cycling'
adata.obs.loc[adata.obs.celltype == '14_med', 'cell_state'] = 'Moderate'

# %%
adata.uns['cell_state_colors'] = ['#ffe2d3', '#fa9471', '#dc2e22', '#d1d3d5'    ]

# %%
adata.obs[time_key] = adata.obs[time_key].astype(int)
fig, axes = plt.subplots(1,2, figsize=(6.4*2, 4.8))
sc.pl.embedding(adata, color=[time_key], basis='draw_graph_fa', ax=axes[0], colorbar_loc=None, frameon=False, show=False, title=[''], legend_loc=None, s=5)
sc.pl.embedding(adata, color=['cell_state'], basis='draw_graph_fa', ax=axes[1], colorbar_loc=None, frameon=False, show=False, title=[''], legend_loc=None, s=5)

# %% [markdown]
# ## Compute Grond Truth based on Clone Information

# %%
adata = sc.read('/storage/xuruihong/repository/pygot_data/03_cellfate/Oren/adata.h5ad')

# %%
adata_processed = cs.tmap.infer_Tmap_from_clonal_info_alone(
    adata,
)
# Out:
# Infer transition map between neighboring time points.
# --> Clonal cell fraction (day 0-1): 0.5151962230746533
# --> Clonal cell fraction (day 1-2): 0.39029653348183213
# --> Clonal cell fraction (day 2-3): 0.387929993964997
# --> Clonal cell fraction (day 1-0): 0.44549631073367674
# --> Clonal cell fraction (day 2-1): 0.3526855763427882
# --> Clonal cell fraction (day 3-2): 0.3175620600222305
# --> Numer of cells that are clonally related -- day 0: 3492  and day 1: 6400
# --> Numer of cells that are clonally related -- day 1: 5607  and day 2: 2922
# --> Numer of cells that are clonally related -- day 2: 3214  and day 3: 8571
# Number of multi-time clones post selection: 2653
# Cell number=56419, Clone number=2653
# --> clonal_cell_id_t1: 12313
# --> Tmap_cell_id_t1: 29429
# Use all clones (naive method)
# Use all clones (naive method)
# Use all clones (naive method)

# %%
cs.tl.fate_map(
    adata_processed,
    selected_fates=['14_high', '14_low'],
    source="clonal_transition_map",
    map_backward=True,
)
# Out:
# Results saved at adata.obs['fate_map_clonal_transition_map_14_high']
# Results saved at adata.obs['fate_map_clonal_transition_map_14_low']

# %%
x0_adata = adata_processed[adata_processed.obs['sample_type'].isin(['0', '3', '7'])] 
x0_adata = x0_adata[(x0_adata.obs['fate_map_clonal_transition_map_14_high'] + x0_adata.obs['fate_map_clonal_transition_map_14_low']) > 0.]

# %%
factor = x0_adata.obs[['fate_map_clonal_transition_map_14_high', 'fate_map_clonal_transition_map_14_low']].sum(axis=1)
x0_adata.obs['fate_map_clonal_transition_map_14_high'] /= factor
x0_adata.obs['fate_map_clonal_transition_map_14_low'] /= factor

# %%
x0_adata.obs['ground_truth'] = x0_adata.obs['fate_map_clonal_transition_map_14_low']

# %%
sc.pl.draw_graph(x0_adata, color=['ground_truth'])

# %%
groundtruth_key = 'ground_truth'

# %% [markdown]
# ## Train Model

# %%
embedding_key = 'X_pca'
velocity_key = 'velocity_pca'
time_key = 'stage_numeric'
cell_type_key = 'celltype'

# %% [markdown]
# ### GOT

# %%
#gots = []
#for i in range(10):
#    model, _ = pygot.tl.traj.fit_velocity_model(adata, embedding_key=embedding_key, x_centric_iter_n=5000, time_key=time_key, path='../pygot_data/03_cellfate/Oren/')
#    gots.append(model)

#for i, got in enumerate(gots):
#    os.system('mkdir ./benchmark_model/GOT/03_cell_fate/oren/'+str(i))
#    torch.save(got, './benchmark_model/GOT/03_cell_fate/oren/'+str(i)+'/model.pkl')
# Out:
# loading saved shortest path profile
# loss :9.0059 best :9.0059: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:43<00:00,  6.12it/s]
# loss :92.5663  best :92.5045: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:54<00:00, 21.32it/s]
# loading saved shortest path profile
# loss :9.0728 best :9.0638: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:45<00:00,  6.05it/s]
# loss :92.3588  best :92.2693: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:49<00:00, 21.76it/s]
# loading saved shortest path profile
# loss :9.0744 best :9.0744: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:42<00:00,  6.16it/s]
# loss :92.0468  best :91.7507: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:48<00:00, 21.93it/s]
# loading saved shortest path profile
# loss :9.0823 best :9.0683: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:31<00:00,  6.62it/s]
# loss :91.7584  best :91.7584: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:47<00:00, 21.97it/s]
# loading saved shortest path profile
# loss :9.0389 best :9.0389: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:34<00:00,  6.49it/s]
# loss :92.3102  best :92.1988: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:52<00:00, 21.47it/s]
# loading saved shortest path profile
# loss :9.1621 best :9.1420: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:33<00:00,  6.52it/s]
# loss :92.2082  best :92.0482: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:49<00:00, 21.74it/s]
# loading saved shortest path profile
# loss :9.1199 best :9.0754: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:37<00:00,  6.35it/s]
# loss :92.0716  best :92.0523: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:52<00:00, 21.52it/s]
# loading saved shortest path profile
# loss :9.0528 best :9.0528: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:36<00:00,  6.38it/s]
# loss :92.3314  best :92.0634: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:52<00:00, 21.51it/s]
# loading saved shortest path profile
# loss :9.1398 best :9.0531: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:31<00:00,  6.62it/s]
# loss :91.8642  best :91.8346: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:49<00:00, 21.79it/s]
# loading saved shortest path profile
# loss :9.0802 best :9.0295: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:33<00:00,  6.51it/s]
# loss :92.8699  best :92.6329: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:49<00:00, 21.76it/s]

# %%
gots = []
for i in range(10):
    gots.append(torch.load('./benchmark_model/GOT/03_cell_fate/oren/'+str(i)+'/model.pkl', map_location='cpu'))

# %% [markdown]
# ### Moscot

# %%
# run with [benchmark]03_cell_fate_cancer_run_moscot.py

# %%
moscot_dfs = []
for e in [1e-1, 5e-1, 1e-2, 5e-2, 1e-3, 5e-3, 1e-4]:
    moscot_dfs.append(pd.read_csv('../pygot_data/03_cellfate/Oren/moscot_v4.0_{}.csv'.format(e), index_col=0))

# %% [markdown]
# ### WOT

# %%
import wot
for e in [1e-1, 5e-1, 1e-2, 5e-2, 2e-2, 3e-2, 5e-3]:
    ot_model = wot.ot.OTModel(adata, epsilon = e, lambda1 = 50, lambda2 = 1, growth_iters = 1, day_field=time_key,) 
    ot_model.compute_all_transport_maps('../pygot_data/03_cellfate/Oren/serum_{}'.format(e))
# Out:
# 2025-02-25 14:47:42,038 - INFO - Computing transport map from 0 to 1
# 2025-02-25 14:54:55,834 - INFO - Computing transport map from 1 to 2
# 2025-02-25 15:01:37,322 - INFO - Computing transport map from 2 to 3
# 2025-02-25 15:16:55,773 - INFO - Computing transport map from 0 to 1
# 2025-02-25 15:20:22,590 - INFO - Computing transport map from 1 to 2
# 2025-02-25 15:26:12,961 - INFO - Computing transport map from 2 to 3
# 2025-02-25 15:40:38,589 - INFO - Computing transport map from 0 to 1
# 2025-02-25 16:06:29,276 - INFO - Computing transport map from 1 to 2
# 2025-02-25 16:34:10,106 - INFO - Computing transport map from 2 to 3

# %%
def get_wot_fate(tmap_model):
    t023 = tmap_model.get_coupling(t0=0, t1=3, covariate=None)
    t123 = tmap_model.get_coupling(t0=1, t1=3, covariate=None)
    t223 = tmap_model.get_coupling(t0=2, t1=3, covariate=None)
    
    def calcu_fate(chain, start_index):
        
        P0 = chain @ (adata.obs[adata.obs[time_key]==3][cell_type_key] == '14_low').astype(int).to_numpy()
        P1 = chain @ (adata.obs[adata.obs[time_key]==3][cell_type_key] == '14_high').astype(int).to_numpy()
        
        
        return pd.DataFrame([P0, P1], columns=start_index, index=['14_low','14_high']).T
    
    
    fate1 = calcu_fate(t023.X, t023.obs.index)
    fate2 = calcu_fate(t123.X, t123.obs.index)
    fate3 = calcu_fate(t223.X, t223.obs.index)
    return pd.concat([fate1, fate2, fate3])

# %%
wot_dfs = []
for e in [1e-1, 5e-1, 1e-2, 5e-2, 2e-2, 3e-2, 5e-3]:
    print(e)
    wot_dfs.append(get_wot_fate(wot.tmap.TransportMapModel.from_directory('../pygot_data/03_cellfate/Oren/serum_{}'.format(e))))
# Out:
# 0.1
# 0.5
# 0.01
# 0.05
# 0.02
# 0.03
# 0.005

# %% [markdown]
# ### Cospar

# %%
def generate_clone_matrix(adata, clone_key):
    
    all_clone = adata.obs[clone_key][adata.obs[clone_key] == adata.obs[clone_key]].unique()
    
    X_clone = np.zeros((len(adata), len(all_clone)))
    adata.obs['idx'] = range(len(adata))
    for i, clone in enumerate(all_clone):
        j = adata.obs.loc[adata.obs[clone_key] == clone]['idx'].tolist()
        X_clone[j, i] = 1
    adata.obsm['X_clone'] = X_clone

# %%
for e in range(10):
    adata_orig = adata.copy()
    generate_clone_matrix(adata_orig, 'lineage_barcode')
    print(adata_orig.obsm['X_clone'].shape)
    selected_clone = np.random.choice(range(adata_orig.obsm['X_clone'].shape[1]), size=int(0.5 * adata_orig.obsm['X_clone'].shape[1]), replace=False)
    adata_orig.obsm['X_clone'] = adata_orig.obsm['X_clone'][:,selected_clone]
    print(adata_orig.obsm['X_clone'].shape)
    adata_orig = cs.pp.initialize_adata_object(adata_orig)
    
    adata_lineage = cs.tmap.infer_Tmap_from_multitime_clones(
            adata_orig,
            clonal_time_points=[ 0,1,2, 3],
            later_time_point=3,
            smooth_array=[ 15, 10, 5],
            sparsity_threshold=0.2,
            intraclone_threshold=0.2,
            max_iter_N=3,
            compute_new=True
    )
    cs.tl.fate_bias(
        adata_lineage,
        selected_fates=["14_low", "14_high"],
        source="transition_map",
        map_backward=True,
        method="norm-sum",
    )
       
    adata_lineage.obs.to_csv('../pygot_data/03_cellfate/Oren/cospar_{}.csv'.format(e))
# Out:
# (56419, 10269)
# (56419, 5134)
# Time points with clonal info: [0 1 2 3]
# WARNING: Default ascending order of time points are: [0 1 2 3]. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.7012672424316406
# Smooth round: 2
# --> Time elapsed: 1.4806346893310547
# Smooth round: 3
# --> Time elapsed: 22.444058656692505
# --> Orignal sparsity=0.10522440271933081, Thresholding
# --> Final sparsity=0.052967936722433266
# similarity matrix truncated (Smooth round=3):  28.697667837142944
# Smooth round: 4
# --> Time elapsed: 39.732022523880005
# --> Orignal sparsity=0.21946558244574815, Thresholding
# --> Final sparsity=0.1034086474700155
# similarity matrix truncated (Smooth round=4):  26.579482078552246
# Smooth round: 5
# --> Time elapsed: 62.493370056152344
# --> Orignal sparsity=0.30392549424187587, Thresholding
# --> Final sparsity=0.15657171544975693
# similarity matrix truncated (Smooth round=5):  27.773173570632935
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 89.37994456291199
# --> Orignal sparsity=0.37826418679941903, Thresholding
# --> Final sparsity=0.20899888402971128
# similarity matrix truncated (Smooth round=6):  28.98761224746704
# Smooth round: 7
# --> Time elapsed: 113.88501930236816
# --> Orignal sparsity=0.4482903394923506, Thresholding
# --> Final sparsity=0.2636416569294272
# similarity matrix truncated (Smooth round=7):  31.68515706062317
# Smooth round: 8
# --> Time elapsed: 156.92753720283508
# --> Orignal sparsity=0.5158645600220859, Thresholding
# --> Final sparsity=0.3186879005222539
# similarity matrix truncated (Smooth round=8):  28.324726343154907
# Smooth round: 9
# --> Time elapsed: 182.11765241622925
# --> Orignal sparsity=0.5772352242987547, Thresholding
# --> Final sparsity=0.37289939716164955
# similarity matrix truncated (Smooth round=9):  33.2909939289093
# Smooth round: 10
# --> Time elapsed: 194.2580075263977
# --> Orignal sparsity=0.6312878665401361, Thresholding
# --> Final sparsity=0.4244552739514214
# similarity matrix truncated (Smooth round=10):  30.0068838596344
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 211.9756669998169
# --> Orignal sparsity=0.6771581721088715, Thresholding
# --> Final sparsity=0.4723047381869333
# similarity matrix truncated (Smooth round=11):  30.637560606002808
# Smooth round: 12
# --> Time elapsed: 263.19314408302307
# --> Orignal sparsity=0.7154079383092996, Thresholding
# --> Final sparsity=0.516012438339891
# similarity matrix truncated (Smooth round=12):  39.66554641723633
# Smooth round: 13
# --> Time elapsed: 243.8365762233734
# --> Orignal sparsity=0.7471289037334592, Thresholding
# --> Final sparsity=0.555658649838066
# similarity matrix truncated (Smooth round=13):  30.359943151474
# Smooth round: 14
# --> Time elapsed: 442.4123287200928
# --> Orignal sparsity=0.7735829600927018, Thresholding
# --> Final sparsity=0.5915407704826479
# similarity matrix truncated (Smooth round=14):  34.68278503417969
# Smooth round: 15
# --> Time elapsed: 350.40304136276245
# --> Orignal sparsity=0.7959077106508254, Thresholding
# --> Final sparsity=0.6239898171506585
# similarity matrix truncated (Smooth round=15):  43.97497844696045
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-3): 0.48539392151077015
# --> Clonal cell fraction (day 3-0): 0.6107447202667655
# --> Numer of cells that are clonally related -- day 0: 3290  and day 3: 16484
# Number of multi-time clones post selection: 753
# Cell number=33768, Clone number=753
# --> clonal_cell_id_t1: 3290
# --> Tmap_cell_id_t1: 6778
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.24285030364990234
# --> Time elapsed:  4.112959861755371
# --> Time elapsed:  0.28683900833129883
# --> Time elapsed:  4.420037746429443
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.18633532524108887
# --> Time elapsed:  3.319465398788452
# --> Time elapsed:  0.24015069007873535
# --> Time elapsed:  3.6781203746795654
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.1678004264831543
# --> Time elapsed:  1.7037396430969238
# --> Time elapsed:  0.2798008918762207
# --> Time elapsed:  2.0664188861846924
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  144.64994931221008
# --> Phase II: time elapsed --  144.9002513885498
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  2.624234199523926
# --> Phase II: time elapsed --  2.8695688247680664
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  2.3542282581329346
# --> Phase II: time elapsed --  2.5932371616363525
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  4.754090785980225
# --> Phase II: time elapsed --  5.433546304702759
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-3): 0.4708339134066546
# --> Clonal cell fraction (day 3-1): 0.6587995553908855
# --> Numer of cells that are clonally related -- day 1: 6764  and day 3: 17781
# Number of multi-time clones post selection: 1116
# Cell number=41356, Clone number=1116
# --> clonal_cell_id_t1: 6764
# --> Tmap_cell_id_t1: 14366
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.7509350776672363
# --> Time elapsed:  5.841870546340942
# --> Time elapsed:  1.5679128170013428
# --> Time elapsed:  6.294467210769653
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.6525125503540039
# --> Time elapsed:  4.284469842910767
# --> Time elapsed:  1.351898193359375
# --> Time elapsed:  4.703580856323242
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.6336650848388672
# --> Time elapsed:  1.978362798690796
# --> Time elapsed:  1.2253520488739014
# --> Time elapsed:  2.3331894874572754
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  287.7576732635498
# --> Phase II: time elapsed --  288.4345557689667
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  4.018427610397339
# --> Phase II: time elapsed --  4.645782232284546
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  4.287235498428345
# --> Phase II: time elapsed --  4.918156623840332
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  6.600688457489014
# --> Phase II: time elapsed --  8.894113779067993
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --------Current initial time point: 2--------
# Step 1: Select time points
# --> Clonal cell fraction (day 2-3): 0.6362100181050091
# --> Clonal cell fraction (day 3-2): 0.6328269729529455
# --> Numer of cells that are clonally related -- day 2: 5271  and day 3: 17080
# Number of multi-time clones post selection: 780
# Cell number=35275, Clone number=780
# --> clonal_cell_id_t1: 5271
# --> Tmap_cell_id_t1: 8285
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.5873885154724121
# --> Time elapsed:  5.2687225341796875
# --> Time elapsed:  0.8103373050689697
# --> Time elapsed:  5.643834590911865
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.46545958518981934
# --> Time elapsed:  4.037737607955933
# --> Time elapsed:  0.6538951396942139
# --> Time elapsed:  4.434406280517578
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.32548952102661133
# --> Time elapsed:  1.8924298286437988
# --> Time elapsed:  0.4498131275177002
# --> Time elapsed:  2.243088483810425
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  321.1102731227875
# --> Phase II: time elapsed --  321.5324306488037
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  6.648046493530273
# --> Phase II: time elapsed --  7.0438151359558105
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  5.087596893310547
# --> Phase II: time elapsed --  5.488828182220459
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  9.005529403686523
# --> Phase II: time elapsed --  10.045884847640991
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 7103.280570983887 s ------------
# Results saved at adata.obs['fate_map_transition_map_14_low']
# Results saved at adata.obs['fate_map_transition_map_14_high']
# Results saved at adata.obs['fate_bias_transition_map_14_low*14_high']
# (56419, 10269)
# (56419, 5134)
# Time points with clonal info: [0 1 2 3]
# WARNING: Default ascending order of time points are: [0 1 2 3]. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.9155476093292236
# Smooth round: 2
# --> Time elapsed: 1.5797803401947021
# Smooth round: 3
# --> Time elapsed: 15.215369939804077
# --> Orignal sparsity=0.10522440271933081, Thresholding
# --> Final sparsity=0.052967936722433266
# similarity matrix truncated (Smooth round=3):  25.0235857963562
# Smooth round: 4
# --> Time elapsed: 38.716124534606934
# --> Orignal sparsity=0.21946558244574815, Thresholding
# --> Final sparsity=0.1034086474700155
# similarity matrix truncated (Smooth round=4):  26.90374732017517
# Smooth round: 5
# --> Time elapsed: 60.66463613510132
# --> Orignal sparsity=0.30392549424187587, Thresholding
# --> Final sparsity=0.15657171544975693
# similarity matrix truncated (Smooth round=5):  28.05201768875122
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 81.15528655052185
# --> Orignal sparsity=0.37826418679941903, Thresholding
# --> Final sparsity=0.20899888402971128
# similarity matrix truncated (Smooth round=6):  30.522977113723755
# Smooth round: 7
# --> Time elapsed: 100.8931200504303
# --> Orignal sparsity=0.4482903394923506, Thresholding
# --> Final sparsity=0.2636416569294272
# similarity matrix truncated (Smooth round=7):  30.47988247871399
# Smooth round: 8
# --> Time elapsed: 176.30500268936157
# --> Orignal sparsity=0.5158645600220859, Thresholding
# --> Final sparsity=0.3186879005222539
# similarity matrix truncated (Smooth round=8):  38.8484411239624
# Smooth round: 9
# --> Time elapsed: 260.167685508728
# --> Orignal sparsity=0.5772352242987547, Thresholding
# --> Final sparsity=0.37289939716164955
# similarity matrix truncated (Smooth round=9):  45.82059955596924
# Smooth round: 10
# --> Time elapsed: 270.599755525589
# --> Orignal sparsity=0.6312878665401361, Thresholding
# --> Final sparsity=0.4244552739514214
# similarity matrix truncated (Smooth round=10):  34.84235882759094
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 388.60544085502625
# --> Orignal sparsity=0.6771581721088715, Thresholding
# --> Final sparsity=0.4723047381869333
# similarity matrix truncated (Smooth round=11):  36.47998809814453
# Smooth round: 12
# --> Time elapsed: 476.79560565948486
# --> Orignal sparsity=0.7154079383092996, Thresholding
# --> Final sparsity=0.516012438339891
# similarity matrix truncated (Smooth round=12):  36.47116708755493
# Smooth round: 13
# --> Time elapsed: 418.196573972702
# --> Orignal sparsity=0.7471289037334592, Thresholding
# --> Final sparsity=0.555658649838066
# similarity matrix truncated (Smooth round=13):  36.558353424072266
# Smooth round: 14
# --> Time elapsed: 487.4648485183716
# --> Orignal sparsity=0.7735829600927018, Thresholding
# --> Final sparsity=0.5915407704826479
# similarity matrix truncated (Smooth round=14):  36.0588915348053
# Smooth round: 15
# --> Time elapsed: 668.17192029953
# --> Orignal sparsity=0.7959077106508254, Thresholding
# --> Final sparsity=0.6239898171506585
# similarity matrix truncated (Smooth round=15):  45.244789838790894
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-3): 0.2477131897314842
# --> Clonal cell fraction (day 3-0): 0.15320489070025936
# --> Numer of cells that are clonally related -- day 0: 1679  and day 3: 4135
# Number of multi-time clones post selection: 747
# Cell number=33768, Clone number=747
# --> clonal_cell_id_t1: 1679
# --> Tmap_cell_id_t1: 6778
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.09942626953125
# --> Time elapsed:  1.5781800746917725
# --> Time elapsed:  0.20602917671203613
# --> Time elapsed:  1.7645893096923828
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.08660888671875
# --> Time elapsed:  1.207137107849121
# --> Time elapsed:  0.19834136962890625
# --> Time elapsed:  1.5544333457946777
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.06667304039001465
# --> Time elapsed:  0.6459364891052246
# --> Time elapsed:  0.1877274513244629
# --> Time elapsed:  0.8004631996154785
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.10265541076660156
# --> Phase II: time elapsed --  0.15488004684448242
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.0798180103302002
# --> Phase II: time elapsed --  0.09461569786071777
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.05355954170227051
# --> Phase II: time elapsed --  0.06823205947875977
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.48723268508911133
# --> Phase II: time elapsed --  0.8695154190063477
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-3): 0.26841152721704026
# --> Clonal cell fraction (day 3-1): 0.1949610967024824
# --> Numer of cells that are clonally related -- day 1: 3856  and day 3: 5262
# Number of multi-time clones post selection: 1116
# Cell number=41356, Clone number=1116
# --> clonal_cell_id_t1: 3856
# --> Tmap_cell_id_t1: 14366
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.530362606048584
# --> Time elapsed:  3.3916525840759277
# --> Time elapsed:  1.5466043949127197
# --> Time elapsed:  3.9151272773742676
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.7707834243774414
# --> Time elapsed:  2.7635977268218994
# --> Time elapsed:  2.924018621444702
# --> Time elapsed:  2.960348606109619
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.26719021797180176
# --> Time elapsed:  0.91802978515625
# --> Time elapsed:  0.9279561042785645
# --> Time elapsed:  1.2279109954833984
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.2746708393096924
# --> Phase II: time elapsed --  0.3867464065551758
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.1500558853149414
# --> Phase II: time elapsed --  0.25322985649108887
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.1422123908996582
# --> Phase II: time elapsed --  0.2512552738189697
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.8566107749938965
# --> Phase II: time elapsed --  2.4609949588775635
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --------Current initial time point: 2--------
# Step 1: Select time points
# --> Clonal cell fraction (day 2-3): 0.19577549788774895
# --> Clonal cell fraction (day 3-2): 0.1677658391997036
# --> Numer of cells that are clonally related -- day 2: 1622  and day 3: 4528
# Number of multi-time clones post selection: 771
# Cell number=35275, Clone number=771
# --> clonal_cell_id_t1: 1622
# --> Tmap_cell_id_t1: 8285
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.1265239715576172
# --> Time elapsed:  2.115870475769043
# --> Time elapsed:  0.5841805934906006
# --> Time elapsed:  2.493069648742676
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.09680867195129395
# --> Time elapsed:  1.737752914428711
# --> Time elapsed:  0.46547865867614746
# --> Time elapsed:  2.0465054512023926
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.06559562683105469
# --> Time elapsed:  0.7264926433563232
# --> Time elapsed:  0.2691488265991211
# --> Time elapsed:  0.9285964965820312
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.13677048683166504
# --> Phase II: time elapsed --  0.15491318702697754
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.07342767715454102
# --> Phase II: time elapsed --  0.09158635139465332
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.07302737236022949
# --> Phase II: time elapsed --  0.09090900421142578
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.5598547458648682
# --> Phase II: time elapsed --  1.0163676738739014
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 7424.569334745407 s ------------
# Results saved at adata.obs['fate_map_transition_map_14_low']
# Results saved at adata.obs['fate_map_transition_map_14_high']
# Results saved at adata.obs['fate_bias_transition_map_14_low*14_high']
# (56419, 10269)
# (56419, 5134)
# Time points with clonal info: [0 1 2 3]
# WARNING: Default ascending order of time points are: [0 1 2 3]. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.9286019802093506
# Smooth round: 2
# --> Time elapsed: 1.591911792755127
# Smooth round: 3
# --> Time elapsed: 15.444930076599121
# --> Orignal sparsity=0.10522440271933081, Thresholding
# --> Final sparsity=0.052967936722433266
# similarity matrix truncated (Smooth round=3):  24.499544143676758
# Smooth round: 4
# --> Time elapsed: 39.185285329818726
# --> Orignal sparsity=0.21946558244574815, Thresholding
# --> Final sparsity=0.1034086474700155
# similarity matrix truncated (Smooth round=4):  25.915371656417847
# Smooth round: 5
# --> Time elapsed: 61.44426655769348
# --> Orignal sparsity=0.30392549424187587, Thresholding
# --> Final sparsity=0.15657171544975693
# similarity matrix truncated (Smooth round=5):  26.875054359436035
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 82.25059866905212
# --> Orignal sparsity=0.37826418679941903, Thresholding
# --> Final sparsity=0.20899888402971128
# similarity matrix truncated (Smooth round=6):  28.9117374420166
# Smooth round: 7
# --> Time elapsed: 102.32534646987915
# --> Orignal sparsity=0.4482903394923506, Thresholding
# --> Final sparsity=0.2636416569294272
# similarity matrix truncated (Smooth round=7):  29.872581243515015
# Smooth round: 8
# --> Time elapsed: 147.4761438369751
# --> Orignal sparsity=0.5158645600220859, Thresholding
# --> Final sparsity=0.3186879005222539
# similarity matrix truncated (Smooth round=8):  29.146694898605347
# Smooth round: 9
# --> Time elapsed: 153.72495007514954
# --> Orignal sparsity=0.5772352242987547, Thresholding
# --> Final sparsity=0.37289939716164955
# similarity matrix truncated (Smooth round=9):  32.12356209754944
# Smooth round: 10
# --> Time elapsed: 178.3810169696808
# --> Orignal sparsity=0.6312878665401361, Thresholding
# --> Final sparsity=0.4244552739514214
# similarity matrix truncated (Smooth round=10):  28.934531450271606
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 221.46615529060364
# --> Orignal sparsity=0.6771581721088715, Thresholding
# --> Final sparsity=0.4723047381869333
# similarity matrix truncated (Smooth round=11):  31.074549198150635
# Smooth round: 12
# --> Time elapsed: 348.8157567977905
# --> Orignal sparsity=0.7154079383092996, Thresholding
# --> Final sparsity=0.516012438339891
# similarity matrix truncated (Smooth round=12):  32.376516819000244
# Smooth round: 13
# --> Time elapsed: 382.7395887374878
# --> Orignal sparsity=0.7471289037334592, Thresholding
# --> Final sparsity=0.555658649838066
# similarity matrix truncated (Smooth round=13):  34.92548894882202
# Smooth round: 14
# --> Time elapsed: 341.4963629245758
# --> Orignal sparsity=0.7735829600927018, Thresholding
# --> Final sparsity=0.5915407704826479
# similarity matrix truncated (Smooth round=14):  36.10719180107117
# Smooth round: 15
# --> Time elapsed: 417.4769711494446
# --> Orignal sparsity=0.7959077106508254, Thresholding
# --> Final sparsity=0.6239898171506585
# similarity matrix truncated (Smooth round=15):  36.89185190200806
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-3): 0.2357627618766598
# --> Clonal cell fraction (day 3-0): 0.1487587995553909
# --> Numer of cells that are clonally related -- day 0: 1598  and day 3: 4015
# Number of multi-time clones post selection: 751
# Cell number=33768, Clone number=751
# --> clonal_cell_id_t1: 1598
# --> Tmap_cell_id_t1: 6778
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.12799596786499023
# --> Time elapsed:  1.4981565475463867
# --> Time elapsed:  0.2273857593536377
# --> Time elapsed:  1.7430295944213867
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.09227585792541504
# --> Time elapsed:  1.1887731552124023
# --> Time elapsed:  0.2253704071044922
# --> Time elapsed:  1.4833402633666992
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.06721162796020508
# --> Time elapsed:  0.5677163600921631
# --> Time elapsed:  0.1850271224975586
# --> Time elapsed:  0.7671077251434326
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.13186001777648926
# --> Phase II: time elapsed --  0.1766057014465332
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.05976533889770508
# --> Phase II: time elapsed --  0.07301735877990723
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.048494815826416016
# --> Phase II: time elapsed --  0.06119966506958008
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.46099042892456055
# --> Phase II: time elapsed --  0.8092150688171387
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-3): 0.259153557009606
# --> Clonal cell fraction (day 3-1): 0.19733234531307892
# --> Numer of cells that are clonally related -- day 1: 3723  and day 3: 5326
# Number of multi-time clones post selection: 1109
# Cell number=41356, Clone number=1109
# --> clonal_cell_id_t1: 3723
# --> Tmap_cell_id_t1: 14366
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.3554496765136719
# --> Time elapsed:  2.8869283199310303
# --> Time elapsed:  1.294410228729248
# --> Time elapsed:  3.191213607788086
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.31114745140075684
# --> Time elapsed:  2.109847068786621
# --> Time elapsed:  1.1123244762420654
# --> Time elapsed:  2.4312117099761963
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.24524354934692383
# --> Time elapsed:  0.838773250579834
# --> Time elapsed:  0.8844921588897705
# --> Time elapsed:  1.1800129413604736
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.2547590732574463
# --> Phase II: time elapsed --  0.3553307056427002
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.1207265853881836
# --> Phase II: time elapsed --  0.20407414436340332
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.11635828018188477
# --> Phase II: time elapsed --  0.2008345127105713
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.6619071960449219
# --> Phase II: time elapsed --  2.0276412963867188
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --------Current initial time point: 2--------
# Step 1: Select time points
# --> Clonal cell fraction (day 2-3): 0.19806879903439953
# --> Clonal cell fraction (day 3-2): 0.1759540570581697
# --> Numer of cells that are clonally related -- day 2: 1641  and day 3: 4749
# Number of multi-time clones post selection: 785
# Cell number=35275, Clone number=785
# --> clonal_cell_id_t1: 1641
# --> Tmap_cell_id_t1: 8285
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.1321256160736084
# --> Time elapsed:  2.3320186138153076
# --> Time elapsed:  0.6044056415557861
# --> Time elapsed:  2.5899672508239746
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.09897780418395996
# --> Time elapsed:  1.7461049556732178
# --> Time elapsed:  0.46803903579711914
# --> Time elapsed:  2.0610625743865967
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.05694437026977539
# --> Time elapsed:  0.7556869983673096
# --> Time elapsed:  0.27033114433288574
# --> Time elapsed:  1.003608226776123
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.1625385284423828
# --> Phase II: time elapsed --  0.18418383598327637
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.08389830589294434
# --> Phase II: time elapsed --  0.10909771919250488
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.0832517147064209
# --> Phase II: time elapsed --  0.10215139389038086
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.7171440124511719
# --> Phase II: time elapsed --  1.1664397716522217
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 6601.048217058182 s ------------
# Results saved at adata.obs['fate_map_transition_map_14_low']
# Results saved at adata.obs['fate_map_transition_map_14_high']
# Results saved at adata.obs['fate_bias_transition_map_14_low*14_high']
# (56419, 10269)
# (56419, 5134)
# Time points with clonal info: [0 1 2 3]
# WARNING: Default ascending order of time points are: [0 1 2 3]. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.7138786315917969
# Smooth round: 2
# --> Time elapsed: 1.3873279094696045
# Smooth round: 3
# --> Time elapsed: 15.08845567703247
# --> Orignal sparsity=0.10522440271933081, Thresholding
# --> Final sparsity=0.052967936722433266
# similarity matrix truncated (Smooth round=3):  25.25171184539795
# Smooth round: 4
# --> Time elapsed: 39.149994134902954
# --> Orignal sparsity=0.21946558244574815, Thresholding
# --> Final sparsity=0.1034086474700155
# similarity matrix truncated (Smooth round=4):  26.912017822265625
# Smooth round: 5
# --> Time elapsed: 60.95824670791626
# --> Orignal sparsity=0.30392549424187587, Thresholding
# --> Final sparsity=0.15657171544975693
# similarity matrix truncated (Smooth round=5):  28.65825653076172
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 84.22094082832336
# --> Orignal sparsity=0.37826418679941903, Thresholding
# --> Final sparsity=0.20899888402971128
# similarity matrix truncated (Smooth round=6):  27.33583927154541
# Smooth round: 7
# --> Time elapsed: 115.0715389251709
# --> Orignal sparsity=0.4482903394923506, Thresholding
# --> Final sparsity=0.2636416569294272
# similarity matrix truncated (Smooth round=7):  28.718833446502686
# Smooth round: 8
# --> Time elapsed: 192.91900253295898
# --> Orignal sparsity=0.5158645600220859, Thresholding
# --> Final sparsity=0.3186879005222539
# similarity matrix truncated (Smooth round=8):  28.512741804122925
# Smooth round: 9
# --> Time elapsed: 166.04301834106445
# --> Orignal sparsity=0.5772352242987547, Thresholding
# --> Final sparsity=0.37289939716164955
# similarity matrix truncated (Smooth round=9):  32.72483825683594
# Smooth round: 10
# --> Time elapsed: 299.8819172382355
# --> Orignal sparsity=0.6312878665401361, Thresholding
# --> Final sparsity=0.4244552739514214
# similarity matrix truncated (Smooth round=10):  30.812801361083984
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 244.63104367256165
# --> Orignal sparsity=0.6771581721088715, Thresholding
# --> Final sparsity=0.4723047381869333
# similarity matrix truncated (Smooth round=11):  30.631163835525513
# Smooth round: 12
# --> Time elapsed: 294.4377775192261
# --> Orignal sparsity=0.7154079383092996, Thresholding
# --> Final sparsity=0.516012438339891
# similarity matrix truncated (Smooth round=12):  33.122787952423096
# Smooth round: 13
# --> Time elapsed: 428.60874819755554
# --> Orignal sparsity=0.7471289037334592, Thresholding
# --> Final sparsity=0.555658649838066
# similarity matrix truncated (Smooth round=13):  39.30446147918701
# Smooth round: 14
# --> Time elapsed: 348.5935654640198
# --> Orignal sparsity=0.7735829600927018, Thresholding
# --> Final sparsity=0.5915407704826479
# similarity matrix truncated (Smooth round=14):  39.94614338874817
# Smooth round: 15
# --> Time elapsed: 384.1817297935486
# --> Orignal sparsity=0.7959077106508254, Thresholding
# --> Final sparsity=0.6239898171506585
# similarity matrix truncated (Smooth round=15):  35.851208209991455
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-3): 0.4833284154617881
# --> Clonal cell fraction (day 3-0): 0.5967765839199703
# --> Numer of cells that are clonally related -- day 0: 3276  and day 3: 16107
# Number of multi-time clones post selection: 721
# Cell number=33768, Clone number=721
# --> clonal_cell_id_t1: 3276
# --> Tmap_cell_id_t1: 6778
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.16058635711669922
# --> Time elapsed:  3.955731153488159
# --> Time elapsed:  0.2978553771972656
# --> Time elapsed:  4.429933309555054
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.12365341186523438
# --> Time elapsed:  3.254544973373413
# --> Time elapsed:  0.2371382713317871
# --> Time elapsed:  3.6395251750946045
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.16201114654541016
# --> Time elapsed:  1.6154811382293701
# --> Time elapsed:  0.2773275375366211
# --> Time elapsed:  1.9806551933288574
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  146.56972479820251
# --> Phase II: time elapsed --  146.7477171421051
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  2.504680633544922
# --> Phase II: time elapsed --  2.666506290435791
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  2.2288730144500732
# --> Phase II: time elapsed --  2.3897545337677
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  4.093820095062256
# --> Phase II: time elapsed --  4.691085577011108
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-3): 0.4626896839760546
# --> Clonal cell fraction (day 3-1): 0.6427565765098184
# --> Numer of cells that are clonally related -- day 1: 6647  and day 3: 17348
# Number of multi-time clones post selection: 1106
# Cell number=41356, Clone number=1106
# --> clonal_cell_id_t1: 6647
# --> Tmap_cell_id_t1: 14366
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.7087576389312744
# --> Time elapsed:  5.812790632247925
# --> Time elapsed:  1.5227906703948975
# --> Time elapsed:  6.27232027053833
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.6351311206817627
# --> Time elapsed:  4.295812368392944
# --> Time elapsed:  1.3522977828979492
# --> Time elapsed:  4.715070962905884
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.5580875873565674
# --> Time elapsed:  1.9636027812957764
# --> Time elapsed:  1.2165462970733643
# --> Time elapsed:  2.3030874729156494
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  272.14578127861023
# --> Phase II: time elapsed --  272.7855339050293
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  3.7610647678375244
# --> Phase II: time elapsed --  4.368106126785278
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  3.531423807144165
# --> Phase II: time elapsed --  4.140021085739136
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  6.031988620758057
# --> Phase II: time elapsed --  8.174151182174683
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --------Current initial time point: 2--------
# Step 1: Select time points
# --> Clonal cell fraction (day 2-3): 0.6333132166566083
# --> Clonal cell fraction (day 3-2): 0.6213041867358281
# --> Numer of cells that are clonally related -- day 2: 5247  and day 3: 16769
# Number of multi-time clones post selection: 774
# Cell number=35275, Clone number=774
# --> clonal_cell_id_t1: 5247
# --> Tmap_cell_id_t1: 8285
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.5367069244384766
# --> Time elapsed:  5.04889988899231
# --> Time elapsed:  0.8083312511444092
# --> Time elapsed:  5.560673475265503
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.423248291015625
# --> Time elapsed:  4.011259317398071
# --> Time elapsed:  0.6559867858886719
# --> Time elapsed:  4.450471878051758
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.2912101745605469
# --> Time elapsed:  1.880713939666748
# --> Time elapsed:  0.44386792182922363
# --> Time elapsed:  2.292487382888794
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  325.75518465042114
# --> Phase II: time elapsed --  326.16344571113586
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  7.1139397621154785
# --> Phase II: time elapsed --  7.498922348022461
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  4.039848566055298
# --> Phase II: time elapsed --  4.434148788452148
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  8.99723744392395
# --> Phase II: time elapsed --  10.016260147094727
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 7375.83954668045 s ------------
# Results saved at adata.obs['fate_map_transition_map_14_low']
# Results saved at adata.obs['fate_map_transition_map_14_high']
# Results saved at adata.obs['fate_bias_transition_map_14_low*14_high']
# (56419, 10269)
# (56419, 5134)
# Time points with clonal info: [0 1 2 3]
# WARNING: Default ascending order of time points are: [0 1 2 3]. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.7205314636230469
# Smooth round: 2
# --> Time elapsed: 1.3491737842559814
# Smooth round: 3
# --> Time elapsed: 15.193845987319946
# --> Orignal sparsity=0.10522440271933081, Thresholding
# --> Final sparsity=0.052967936722433266
# similarity matrix truncated (Smooth round=3):  24.305330276489258
# Smooth round: 4
# --> Time elapsed: 38.96770000457764
# --> Orignal sparsity=0.21946558244574815, Thresholding
# --> Final sparsity=0.1034086474700155
# similarity matrix truncated (Smooth round=4):  26.789763927459717
# Smooth round: 5
# --> Time elapsed: 61.06353569030762
# --> Orignal sparsity=0.30392549424187587, Thresholding
# --> Final sparsity=0.15657171544975693
# similarity matrix truncated (Smooth round=5):  28.490889310836792
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 81.65902400016785
# --> Orignal sparsity=0.37826418679941903, Thresholding
# --> Final sparsity=0.20899888402971128
# similarity matrix truncated (Smooth round=6):  28.968146324157715
# Smooth round: 7
# --> Time elapsed: 101.6003487110138
# --> Orignal sparsity=0.4482903394923506, Thresholding
# --> Final sparsity=0.2636416569294272
# similarity matrix truncated (Smooth round=7):  27.408185243606567
# Smooth round: 8
# --> Time elapsed: 126.12742853164673
# --> Orignal sparsity=0.5158645600220859, Thresholding
# --> Final sparsity=0.3186879005222539
# similarity matrix truncated (Smooth round=8):  27.974337816238403
# Smooth round: 9
# --> Time elapsed: 155.72613954544067
# --> Orignal sparsity=0.5772352242987547, Thresholding
# --> Final sparsity=0.37289939716164955
# similarity matrix truncated (Smooth round=9):  28.66472053527832
# Smooth round: 10
# --> Time elapsed: 179.80998849868774
# --> Orignal sparsity=0.6312878665401361, Thresholding
# --> Final sparsity=0.4244552739514214
# similarity matrix truncated (Smooth round=10):  28.999028205871582
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 214.63226437568665
# --> Orignal sparsity=0.6771581721088715, Thresholding
# --> Final sparsity=0.4723047381869333
# similarity matrix truncated (Smooth round=11):  31.110321044921875
# Smooth round: 12
# --> Time elapsed: 269.1387691497803
# --> Orignal sparsity=0.7154079383092996, Thresholding
# --> Final sparsity=0.516012438339891
# similarity matrix truncated (Smooth round=12):  31.73843502998352
# Smooth round: 13
# --> Time elapsed: 343.02892565727234
# --> Orignal sparsity=0.7471289037334592, Thresholding
# --> Final sparsity=0.555658649838066
# similarity matrix truncated (Smooth round=13):  33.803725481033325
# Smooth round: 14
# --> Time elapsed: 414.23516488075256
# --> Orignal sparsity=0.7735829600927018, Thresholding
# --> Final sparsity=0.5915407704826479
# similarity matrix truncated (Smooth round=14):  37.85748863220215
# Smooth round: 15
# --> Time elapsed: 537.2520723342896
# --> Orignal sparsity=0.7959077106508254, Thresholding
# --> Final sparsity=0.6239898171506585
# similarity matrix truncated (Smooth round=15):  33.8285551071167
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-3): 0.2412215992918265
# --> Clonal cell fraction (day 3-0): 0.14394220081511672
# --> Numer of cells that are clonally related -- day 0: 1635  and day 3: 3885
# Number of multi-time clones post selection: 730
# Cell number=33768, Clone number=730
# --> clonal_cell_id_t1: 1635
# --> Tmap_cell_id_t1: 6778
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.0986945629119873
# --> Time elapsed:  1.421219825744629
# --> Time elapsed:  0.21485137939453125
# --> Time elapsed:  1.7244617938995361
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.07611870765686035
# --> Time elapsed:  1.1827232837677002
# --> Time elapsed:  0.20210790634155273
# --> Time elapsed:  1.3740053176879883
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.04264116287231445
# --> Time elapsed:  0.6010355949401855
# --> Time elapsed:  0.18452739715576172
# --> Time elapsed:  0.7580819129943848
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.08717107772827148
# --> Phase II: time elapsed --  0.10181069374084473
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.04670357704162598
# --> Phase II: time elapsed --  0.05987548828125
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.04642534255981445
# --> Phase II: time elapsed --  0.05959916114807129
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.43206024169921875
# --> Phase II: time elapsed --  0.7924139499664307
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-3): 0.2617986913545872
# --> Clonal cell fraction (day 3-1): 0.18810670618747685
# --> Numer of cells that are clonally related -- day 1: 3761  and day 3: 5077
# Number of multi-time clones post selection: 1094
# Cell number=41356, Clone number=1094
# --> clonal_cell_id_t1: 3761
# --> Tmap_cell_id_t1: 14366
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.36461901664733887
# --> Time elapsed:  2.837383270263672
# --> Time elapsed:  1.2943572998046875
# --> Time elapsed:  3.0979514122009277
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.3011820316314697
# --> Time elapsed:  1.9408233165740967
# --> Time elapsed:  1.0745065212249756
# --> Time elapsed:  2.260179042816162
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.2495405673980713
# --> Time elapsed:  0.8679125308990479
# --> Time elapsed:  0.847538948059082
# ...
# --> Phase I: time elapsed --  0.07726192474365234
# --> Phase II: time elapsed --  0.09420251846313477
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.04026937484741211
# --> Phase II: time elapsed --  0.05367875099182129
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.03975939750671387
# --> Phase II: time elapsed --  0.0533144474029541
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.41864442825317383
# --> Phase II: time elapsed --  0.7677488327026367
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-3): 0.25971042739802314
# --> Clonal cell fraction (day 3-1): 0.18177102630603928
# --> Numer of cells that are clonally related -- day 1: 3731  and day 3: 4906
# Number of multi-time clones post selection: 1084
# Cell number=41356, Clone number=1084
# --> clonal_cell_id_t1: 3731
# --> Tmap_cell_id_t1: 14366
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.3456859588623047
# --> Time elapsed:  2.781931161880493
# --> Time elapsed:  1.2847542762756348
# --> Time elapsed:  3.0698299407958984
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.2874453067779541
# --> Time elapsed:  1.9737458229064941
# --> Time elapsed:  1.0660896301269531
# --> Time elapsed:  2.302385091781616
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.23344874382019043
# --> Time elapsed:  0.8248569965362549
# --> Time elapsed:  0.8650763034820557
# --> Time elapsed:  1.0629911422729492
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.22035527229309082
# --> Phase II: time elapsed --  0.3215365409851074
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.10072565078735352
# --> Phase II: time elapsed --  0.19722414016723633
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.09708595275878906
# --> Phase II: time elapsed --  0.18833327293395996
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.7270357608795166
# --> Phase II: time elapsed --  2.047776699066162
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --------Current initial time point: 2--------
# Step 1: Select time points
# --> Clonal cell fraction (day 2-3): 0.1939649969824985
# --> Clonal cell fraction (day 3-2): 0.1550574286772879
# --> Numer of cells that are clonally related -- day 2: 1607  and day 3: 4185
# Number of multi-time clones post selection: 767
# Cell number=35275, Clone number=767
# --> clonal_cell_id_t1: 1607
# --> Tmap_cell_id_t1: 8285
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.11524629592895508
# --> Time elapsed:  2.0876526832580566
# --> Time elapsed:  0.5637369155883789
# --> Time elapsed:  2.3366124629974365
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.09631919860839844
# --> Time elapsed:  1.6269326210021973
# --> Time elapsed:  0.4651308059692383
# --> Time elapsed:  1.9051032066345215
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.0659475326538086
# --> Time elapsed:  0.6828413009643555
# --> Time elapsed:  0.26576828956604004
# --> Time elapsed:  0.9281642436981201
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.1132054328918457
# --> Phase II: time elapsed --  0.13057255744934082
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.07946062088012695
# --> Phase II: time elapsed --  0.0969085693359375
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.05633211135864258
# --> Phase II: time elapsed --  0.07322001457214355
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.4958500862121582
# --> Phase II: time elapsed --  0.957573652267456
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 5592.159117698669 s ------------
# Results saved at adata.obs['fate_map_transition_map_14_low']
# Results saved at adata.obs['fate_map_transition_map_14_high']
# Results saved at adata.obs['fate_bias_transition_map_14_low*14_high']
# (56419, 10269)
# (56419, 5134)
# Time points with clonal info: [0 1 2 3]
# WARNING: Default ascending order of time points are: [0 1 2 3]. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.7015590667724609
# Smooth round: 2
# --> Time elapsed: 1.3289079666137695
# Smooth round: 3
# --> Time elapsed: 15.23625659942627
# --> Orignal sparsity=0.10522440271933081, Thresholding
# --> Final sparsity=0.052967936722433266
# similarity matrix truncated (Smooth round=3):  24.405797243118286
# Smooth round: 4
# --> Time elapsed: 38.90366291999817
# --> Orignal sparsity=0.21946558244574815, Thresholding
# --> Final sparsity=0.1034086474700155
# similarity matrix truncated (Smooth round=4):  27.27180004119873
# Smooth round: 5
# --> Time elapsed: 61.42601251602173
# --> Orignal sparsity=0.30392549424187587, Thresholding
# --> Final sparsity=0.15657171544975693
# similarity matrix truncated (Smooth round=5):  28.335754871368408
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 81.88124465942383
# --> Orignal sparsity=0.37826418679941903, Thresholding
# --> Final sparsity=0.20899888402971128
# similarity matrix truncated (Smooth round=6):  27.183177947998047
# Smooth round: 7
# --> Time elapsed: 102.57308197021484
# --> Orignal sparsity=0.4482903394923506, Thresholding
# --> Final sparsity=0.2636416569294272
# similarity matrix truncated (Smooth round=7):  30.307188034057617
# Smooth round: 8
# --> Time elapsed: 124.68828558921814
# --> Orignal sparsity=0.5158645600220859, Thresholding
# --> Final sparsity=0.3186879005222539
# similarity matrix truncated (Smooth round=8):  27.8832004070282
# Smooth round: 9
# --> Time elapsed: 145.76072096824646
# --> Orignal sparsity=0.5772352242987547, Thresholding
# --> Final sparsity=0.37289939716164955
# similarity matrix truncated (Smooth round=9):  28.440513134002686
# Smooth round: 10
# --> Time elapsed: 162.77525925636292
# --> Orignal sparsity=0.6312878665401361, Thresholding
# --> Final sparsity=0.4244552739514214
# similarity matrix truncated (Smooth round=10):  28.574482679367065
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 192.4751136302948
# --> Orignal sparsity=0.6771581721088715, Thresholding
# --> Final sparsity=0.4723047381869333
# similarity matrix truncated (Smooth round=11):  30.10613512992859
# Smooth round: 12
# --> Time elapsed: 207.7871494293213
# --> Orignal sparsity=0.7154079383092996, Thresholding
# --> Final sparsity=0.516012438339891
# similarity matrix truncated (Smooth round=12):  30.06647753715515
# Smooth round: 13
# --> Time elapsed: 222.3392367362976
# --> Orignal sparsity=0.7471289037334592, Thresholding
# --> Final sparsity=0.555658649838066
# similarity matrix truncated (Smooth round=13):  29.681604862213135
# Smooth round: 14
# --> Time elapsed: 233.37119126319885
# --> Orignal sparsity=0.7735829600927018, Thresholding
# --> Final sparsity=0.5915407704826479
# similarity matrix truncated (Smooth round=14):  29.537877559661865
# Smooth round: 15
# --> Time elapsed: 249.1944649219513
# --> Orignal sparsity=0.7959077106508254, Thresholding
# --> Final sparsity=0.6239898171506585
# similarity matrix truncated (Smooth round=15):  29.45971441268921
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-3): 0.24889347890233107
# --> Clonal cell fraction (day 3-0): 0.15153760652093368
# --> Numer of cells that are clonally related -- day 0: 1687  and day 3: 4090
# Number of multi-time clones post selection: 761
# Cell number=33768, Clone number=761
# --> clonal_cell_id_t1: 1687
# --> Tmap_cell_id_t1: 6778
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.0939798355102539
# --> Time elapsed:  1.451629400253296
# --> Time elapsed:  0.21152853965759277
# --> Time elapsed:  1.7662742137908936
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.08878087997436523
# --> Time elapsed:  1.1762480735778809
# --> Time elapsed:  0.21391701698303223
# --> Time elapsed:  1.4536335468292236
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.05327129364013672
# --> Time elapsed:  0.576310396194458
# --> Time elapsed:  0.19043779373168945
# --> Time elapsed:  0.7481269836425781
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.09195876121520996
# --> Phase II: time elapsed --  0.10729026794433594
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.04661226272583008
# --> Phase II: time elapsed --  0.06223464012145996
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.04620981216430664
# --> Phase II: time elapsed --  0.06168103218078613
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.43578481674194336
# --> Phase II: time elapsed --  0.8125312328338623
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-3): 0.259153557009606
# --> Clonal cell fraction (day 3-1): 0.19110781771026306
# --> Numer of cells that are clonally related -- day 1: 3723  and day 3: 5158
# Number of multi-time clones post selection: 1097
# Cell number=41356, Clone number=1097
# --> clonal_cell_id_t1: 3723
# --> Tmap_cell_id_t1: 14366
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.3457221984863281
# --> Time elapsed:  2.858668088912964
# --> Time elapsed:  1.2846643924713135
# --> Time elapsed:  3.1726322174072266
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.28368210792541504
# --> Time elapsed:  2.1064093112945557
# --> Time elapsed:  1.0669090747833252
# --> Time elapsed:  2.3403353691101074
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.23412513732910156
# --> Time elapsed:  0.882317304611206
# --> Time elapsed:  0.8612387180328369
# --> Time elapsed:  1.1134538650512695
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.23682498931884766
# --> Phase II: time elapsed --  0.33602213859558105
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.14533281326293945
# --> Phase II: time elapsed --  0.23955345153808594
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.14208388328552246
# --> Phase II: time elapsed --  0.2417449951171875
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.6282503604888916
# --> Phase II: time elapsed --  2.0572478771209717
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --------Current initial time point: 2--------
# Step 1: Select time points
# --> Clonal cell fraction (day 2-3): 0.18780929390464696
# --> Clonal cell fraction (day 3-2): 0.17084105224157095
# --> Numer of cells that are clonally related -- day 2: 1556  and day 3: 4611
# Number of multi-time clones post selection: 775
# Cell number=35275, Clone number=775
# --> clonal_cell_id_t1: 1556
# --> Tmap_cell_id_t1: 8285
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.11142158508300781
# --> Time elapsed:  2.1211140155792236
# --> Time elapsed:  0.5695652961730957
# --> Time elapsed:  2.4748849868774414
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.09114885330200195
# --> Time elapsed:  1.6818339824676514
# --> Time elapsed:  0.4588503837585449
# --> Time elapsed:  1.909684658050537
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.06173229217529297
# --> Time elapsed:  0.7152864933013916
# --> Time elapsed:  0.2580983638763428
# --> Time elapsed:  0.9540939331054688
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.14463114738464355
# --> Phase II: time elapsed --  0.1629807949066162
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.10765695571899414
# --> Phase II: time elapsed --  0.1257317066192627
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.07949471473693848
# --> Phase II: time elapsed --  0.09754276275634766
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.5316109657287598
# --> Phase II: time elapsed --  0.9947640895843506
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 5565.0494158267975 s ------------
# Results saved at adata.obs['fate_map_transition_map_14_low']
# Results saved at adata.obs['fate_map_transition_map_14_high']
# Results saved at adata.obs['fate_bias_transition_map_14_low*14_high']

# %%
cospar_dfs = []
for e in range(10):
    cospar_dfs.append(pd.read_csv('../pygot_data/03_cellfate/Oren/cospar_{}.csv'.format(e),index_col=0))

# %% [markdown]
# ## Cell fate computation

# %%
got_dfs = []
for got in gots:
    adata.obsm[velocity_key] = pygot.tl.traj.latent_velocity(adata, got, embedding_key=embedding_key, time_key=time_key)
    cellfate = pygot.tl.analysis.CellFate()
    cellfate.fit(adata, embedding_key=embedding_key, velocity_key=velocity_key, cell_type_key=cell_type_key,
                 sde=True, D=1.,
                  target_cell_types=['14_low', '14_high'], mutual=False)
    adata.obs['got_fate_bias'] = hf.get_fate_bias(adata.obsm['descendant'],['14_low', '14_high'] )
    got_dfs.append(adata.obs.copy())
# Out:
# 2025-03-27 22:33:45 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:33:45 	 Compute transition between 0 and 1
# 2025-03-27 22:33:47 	 Compute velocity graph
# Scale factor: 5.2752633
# Scale factor: 5.2752633
# 2025-03-27 22:34:45 	 Convert into markov chain
# 2025-03-27 22:34:45 	 Solve abosorbing probabilities
# 2025-03-27 22:34:46 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:34:46 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:34:46 	 Compute transition between 0 and 1
# 2025-03-27 22:34:49 	 Compute velocity graph
# Scale factor: 5.329376
# Scale factor: 5.329376
# 2025-03-27 22:35:20 	 Convert into markov chain
# 2025-03-27 22:35:21 	 Solve abosorbing probabilities
# 2025-03-27 22:35:21 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:35:22 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:35:22 	 Compute transition between 0 and 1
# 2025-03-27 22:35:25 	 Compute velocity graph
# Scale factor: 5.2360606
# Scale factor: 5.2360606
# 2025-03-27 22:35:53 	 Convert into markov chain
# 2025-03-27 22:35:54 	 Solve abosorbing probabilities
# 2025-03-27 22:35:54 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:35:55 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:35:55 	 Compute transition between 0 and 1
# 2025-03-27 22:35:58 	 Compute velocity graph
# Scale factor: 5.200422
# Scale factor: 5.200422
# 2025-03-27 22:36:30 	 Convert into markov chain
# 2025-03-27 22:36:30 	 Solve abosorbing probabilities
# 2025-03-27 22:36:31 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:36:31 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:36:31 	 Compute transition between 0 and 1
# 2025-03-27 22:36:34 	 Compute velocity graph
# Scale factor: 5.32103
# Scale factor: 5.32103
# 2025-03-27 22:37:04 	 Convert into markov chain
# 2025-03-27 22:37:04 	 Solve abosorbing probabilities
# 2025-03-27 22:37:05 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:37:05 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:37:05 	 Compute transition between 0 and 1
# 2025-03-27 22:37:09 	 Compute velocity graph
# Scale factor: 5.1144166
# Scale factor: 5.1144166
# 2025-03-27 22:37:38 	 Convert into markov chain
# 2025-03-27 22:37:38 	 Solve abosorbing probabilities
# 2025-03-27 22:37:39 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:37:40 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:37:40 	 Compute transition between 0 and 1
# 2025-03-27 22:37:42 	 Compute velocity graph
# Scale factor: 5.304504
# Scale factor: 5.304504
# 2025-03-27 22:38:16 	 Convert into markov chain
# 2025-03-27 22:38:16 	 Solve abosorbing probabilities
# 2025-03-27 22:38:16 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:38:17 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:38:17 	 Compute transition between 0 and 1
# 2025-03-27 22:38:20 	 Compute velocity graph
# Scale factor: 5.0502825
# Scale factor: 5.0502825
# 2025-03-27 22:38:49 	 Convert into markov chain
# 2025-03-27 22:38:50 	 Solve abosorbing probabilities
# 2025-03-27 22:38:50 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:38:51 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:38:51 	 Compute transition between 0 and 1
# 2025-03-27 22:38:54 	 Compute velocity graph
# Scale factor: 5.2288733
# Scale factor: 5.2288733
# 2025-03-27 22:39:23 	 Convert into markov chain
# 2025-03-27 22:39:23 	 Solve abosorbing probabilities
# 2025-03-27 22:39:23 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:39:24 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:39:24 	 Compute transition between 0 and 1
# 2025-03-27 22:39:26 	 Compute velocity graph
# Scale factor: 5.152817
# Scale factor: 5.152817
# 2025-03-27 22:39:58 	 Convert into markov chain
# 2025-03-27 22:39:58 	 Solve abosorbing probabilities
# 2025-03-27 22:39:58 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']

# %%
pred_bias_gots = [df.loc[x0_adata.obs.index]['got_fate_bias'].to_numpy() for df in got_dfs]
gots_res = [hf.correlation_2x2(pred_bias_gots[i], x0_adata, fate_bias_key=groundtruth_key, embedding_key=embedding_key).to_numpy() for i in range(len(pred_bias_gots))]
np.array(gots_res)[:,1,0]
# Out:
# array([0.35013497, 0.34810794, 0.33766841, 0.34267915, 0.36119431,
#        0.36806906, 0.3550321 , 0.35317507, 0.35175476, 0.34281404])

# %%
#GOT
pred_bias_gots = [df.loc[x0_adata.obs.index]['got_fate_bias'].to_numpy() for df in got_dfs]


#WOT
pred_bias_wot = [df.loc[x0_adata.obs.index].apply(lambda x: x['14_low'] / (x['14_low'] + x['14_high']), axis=1 ).to_numpy() for df in wot_dfs] 


#MOSCOT
pred_bias_moscot = [df.loc[x0_adata.obs.index]['moscot_fate_bias'].apply(lambda x: .5 if np.isnan(x) else x).to_numpy() for df in moscot_dfs]

#Cospar
pred_bias_cospars = [df.loc[x0_adata.obs.index]['fate_bias_transition_map_14_low*14_high'].to_numpy() for df in cospar_dfs]
#    pred_bias_cospars.append(pd.read_csv('./benchmark_model/Cospar/03_cell_fate/reprogramming_fate/cospar_{}.csv'.format(i), index_col=0).loc[x0_adata.obs.index.to_series().astype(int)]['fate_bias_transition_map_Reprogrammed*Failed'].to_numpy())

# %% [markdown]
# ## Benchmark

# %%
wot_res = [hf.correlation_2x2(pred_bias_wot[i],  x0_adata, fate_bias_key=groundtruth_key, embedding_key=embedding_key).to_numpy() for i in range(len(pred_bias_wot))]
moscot_res = [hf.correlation_2x2(pred_bias_moscot[i],  x0_adata, fate_bias_key=groundtruth_key, embedding_key=embedding_key).to_numpy() for i in range(len(pred_bias_moscot))]
gots_res = [hf.correlation_2x2(pred_bias_gots[i], x0_adata, fate_bias_key=groundtruth_key, embedding_key=embedding_key).to_numpy() for i in range(len(pred_bias_gots))]
cospar_res = [hf.correlation_2x2(pred_bias_cospars[i], x0_adata, fate_bias_key=groundtruth_key, embedding_key=embedding_key).to_numpy() for i in range(len(pred_bias_cospars))]

# %%
pcc_df =  pd.DataFrame([np.concatenate([
            np.array(gots_res)[:,1,0],
            np.array(moscot_res)[:,1,0],
            np.array(cospar_res)[:,1,0],
            np.array(wot_res)[:,1,0],
            
            ]), ['GOT']*len(gots_res)  + ["Moscot"]*len(moscot_res) + ["Cospar\n(with clone)"]*len(cospar_res) + ['WOT']*len(wot_res)  
                       ], index=['PCC', 'Method']).T

# %%
pcc_df.to_csv('./results/03_cellfate/cancer_res.csv')

# %%
pcc_df = pd.read_csv('./results/03_cellfate/cancer_res.csv')

# %%
import mplscience
mplscience.set_style(reset_current=True)
plt.rcParams['font.sans-serif'] = ['Arial']
pal=sns.color_palette()
paln=pal.copy()
paln[0]=np.array([13,111,178])/255

# %%
palette = {
    'GOT':'#049e74',
    'Cospar\n(with clone)':'#0066a4',
    'Moscot': '#d46126',
    'WOT':'#e5a023',
}
#palette = 'Accent'

ax = sns.barplot(
    x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
    
    capsize=.3,
    err_kws={"linewidth": 1., 'color':'grey'},
    palette=palette,
    order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'],
    #fill=False,
    legend=False,
    alpha=0.5
    
)


sns.stripplot(
    x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
    
    dodge=False,  # 分开展示不同方法
    jitter=0.2,  # 控制抖动幅度
    palette=palette, 
    alpha=1.,
    legend=False,
    #ax=ax,
    size=5,
    order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT']
)
plt.ylim(0.15, 0.38)
plt.show()

# %%
scc, pcc, mse, r2, auc = hf.positive_control(x0_adata, embedding_key, groundtruth_key)
pcc_df = pd.concat([pcc_df, pd.DataFrame([pcc, 'supervised LR'], index=['PCC', 'Method']).T])
sns.barplot(x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
            capsize=.1, ci="sd", order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'], 
            palette='Accent')  
sns.swarmplot(x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
              color="black", alpha=.5, order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT']) 

plt.axhline(y=pcc_df.loc[pcc_df['Method'] == 'supervised LR']['PCC'].tolist()[0], color='red', linestyle='--', label='supervised linear regression')
plt.show()
plt.close()
# Out:
# SCC: 0.3309011550809994
# PCC: 0.4152088390756353
# Mean Squared Error: 0.11793959753296815
# R-squared: 0.17079911631567313
# ROC-AUC: 0.7176764141445919

# %%
pcc_df.groupby('Method').apply(lambda x: x.PCC.mean())
# Out:
# Method
# Cospar\n(with clone)    0.300664
# GOT                     0.351063
# Moscot                  0.253568
# WOT                     0.293052
# supervised LR           0.415209
# dtype: float64

# %%
show_idx = x0_adata.obs.index

basis='draw_graph_fa'

# %%
import matplotlib.colors as mcolors

#colors = ["blue", "white", "red"]
#custom_cmap = mcolors.LinearSegmentedColormap.from_list("custom_cmap", colors)
custom_cmap='coolwarm'

norm = mcolors.TwoSlopeNorm(vmin=0., vcenter=0.5, vmax=1.)
fig, axes = plt.subplots(1, 5, figsize=(6.4*4, 4.8))

sc.pl.embedding(x0_adata[show_idx], color=groundtruth_key, ax=axes[0], basis=basis, cmap='coolwarm', colorbar_loc=None, frameon=False, title='', show=False)

print(hf.correlation_2x2(pred_bias_gots[np.array(gots_res)[:,1,0].argsort()[len(gots_res) // 2]], x0_adata, groundtruth_key, embedding_key))
sc.pl.embedding(x0_adata[show_idx], color='pred_fate_bias', ax=axes[1], basis=basis, cmap=custom_cmap, norm=norm, colorbar_loc=None, frameon=False, title='', show=False)

print(hf.correlation_2x2(pred_bias_cospars[np.array(cospar_res)[:,1,0].argsort()[len(cospar_res) // 2]], x0_adata, groundtruth_key, embedding_key))
sc.pl.embedding(x0_adata[show_idx], color='pred_fate_bias', ax=axes[2], basis=basis, cmap=custom_cmap, norm=norm, colorbar_loc=None, frameon=False, title='', show=False)

print(hf.correlation_2x2(pred_bias_moscot[np.array(moscot_res)[:,1,0].argsort()[len(moscot_res) // 2]], x0_adata, groundtruth_key, embedding_key))
sc.pl.embedding(x0_adata[show_idx], color='pred_fate_bias', ax=axes[3], basis=basis, cmap=custom_cmap, norm=norm, colorbar_loc=None, frameon=False, title='', show=False)

print(hf.correlation_2x2(pred_bias_wot[np.array(wot_res)[:,1,0].argsort()[len(wot_res) // 2]], x0_adata, groundtruth_key, embedding_key))
sc.pl.embedding(x0_adata[show_idx], color='pred_fate_bias', ax=axes[4], basis=basis, cmap=custom_cmap, norm=norm, colorbar_loc=None, frameon=False, title='', show=False)
#plt.show()
# Out:
#      pred vs gt  sm pred vs gt  pred vs sm gt  sm pred vs sm gt
# scc    0.266007       0.246090       0.316927          0.310563
# pcc    0.351755       0.323394       0.484296          0.486743
# mse    0.137516       0.134672       0.052428          0.042111
# r2    -1.977199      -3.566436      -0.135060         -0.427907
# auc    0.668969       0.655122       0.821389          0.820377
#      pred vs gt  sm pred vs gt  pred vs sm gt  sm pred vs sm gt
# scc    0.257503       0.246412       0.333207          0.347161
# pcc    0.323437       0.288687       0.470331          0.455065
# mse    0.185782       0.184546       0.098044          0.092778
# r2    -8.584777     -12.500085      -4.058242         -5.787021
# auc    0.664218       0.658574       0.820136          0.822624
#      pred vs gt  sm pred vs gt  pred vs sm gt  sm pred vs sm gt
# scc    0.254960       0.238513       0.295750          0.296781
# pcc    0.245338       0.262548       0.323581          0.374546
# mse    0.293371       0.218642       0.221728          0.137595
# r2    -0.625586      -1.165820      -0.228609         -0.362984
# auc    0.663757       0.651763       0.809524          0.806758
#      pred vs gt  sm pred vs gt  pred vs sm gt  sm pred vs sm gt
# scc    0.266203       0.251031       0.303764          0.311098
# pcc    0.290781       0.300750       0.377513          0.429284
# mse    0.223330       0.170756       0.151446          0.087275
# r2    -0.493514      -0.971431      -0.012790         -0.007614
# auc    0.671034       0.659423       0.813910          0.816731

# %%
ent(pred_bias_moscot[-4])
# Out:
# 0.2184553631376289

# %%
def ent(x):
    return -np.sum(np.log(x[(x>0.05)&(x<0.95)])*x[(x>0.05)&(x<0.95)]) / len(x)
    
ent_df =  pd.DataFrame([np.concatenate([
            [ent(x) for x in pred_bias_gots],
            [ent(x) for x in pred_bias_moscot],
            [ent(x) for x in pred_bias_cospars],
            [ent(x) for x in pred_bias_wot],
            
            ]), ['GOT']*len(gots_res)  + ["Moscot"]*len(moscot_res) + ["Cospar\n(with clone)"]*len(cospar_res) + ['WOT']*len(wot_res)  
                       # + ['OT-CFM']*len(wot_res) + ['MIOFlow']*len(mioflows_res) 
                       ], index=['ENT', 'Method']).T


palette = {
    'GOT':'#049e74',
    'Cospar\n(with clone)':'#0066a4',
    'Moscot': '#d46126',
    'WOT':'#e5a023',
}


ax = sns.barplot(
    x='Method', y='ENT', data=ent_df.loc[ent_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
    
    capsize=.3,
    errorbar=None,
    err_kws={"linewidth": 1., 'color':'grey'},
    palette=palette,
    order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'],
    #fill=False,
    legend=False,
    alpha=0.5
    
)




plt.show()

# %%
ent_df.to_csv('./results/03_cellfate/cancer_ent.csv')

# %%
import pandas as pd
pcc_df = pd.read_csv('./results/03_cellfate/')

# %%
pcc_df.groupby('Method').apply(lambda x: x.PCC.std())
# Out:
# /tmp/ipykernel_2459586/2468531129.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   pcc_df.groupby('Method').apply(lambda x: x.PCC.std())
# Method
# Cospar\n(with clone)    0.046561
# GOT                     0.009067
# Moscot                  0.025991
# WOT                     0.021408
# supervised LR                NaN
# dtype: float64
