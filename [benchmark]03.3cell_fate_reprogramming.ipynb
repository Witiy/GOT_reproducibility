# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import scanpy as sc
import torch
from tqdm import tqdm
import torchdiffeq
import pygot
import pandas as pd
import seaborn as sns
import cospar as cs
from help_function import cell_fate_helper as hf
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# %matplotlib inline

# %%
import random
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.cuda.manual_seed(seed)
 
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Loading Data

# %%
adata = sc.read_h5ad("../pygot_data/03_cellfate/adata_repro.h5ad")

time_key = 'time_info'
cell_type_key = 'state_info'
embedding_key = 'X_pca'
sc.pl.embedding(adata,basis='emb',color=[time_key, cell_type_key, 'Recompute_fate_bias'], color_map='coolwarm',ncols=1)
dim = 30
adata.obsm[embedding_key] = adata.obsm[embedding_key][:,:dim]
#adata.varm['PCs'] = adata.varm['PCs'][:, :dim]
adata = adata[adata.obs.sort_values(time_key).index]


ts = np.sort(np.unique(adata.obs[time_key]))
ts_map = dict(zip(ts, range(len(ts))))
adata.obs['time_label'] = adata.obs[time_key].replace(ts_map).astype(int)
#x0_adata = adata[ (adata.obs['time_label'] < 2) & (adata.obs['benchmark'] == True)]

embedding_key = 'X_pca'
velocity_key = 'velocity_pca'
time_key = 'time_label'

# %% [markdown]
# ## Compute Ground Truth based on Clonal Information

# %%
adata_processed = cs.tmap.infer_Tmap_from_clonal_info_alone(
    adata,      
)
cs.tl.fate_map(
    adata_processed,
    selected_fates=["Reprogrammed", "Failed"],
    source="clonal_transition_map",
    map_backward=True,
    method="norm-sum",
    
)
adata_processed.obs['Cospar_fate_bias'] = adata_processed.obs['fate_map_clonal_transition_map_Reprogrammed'] / (adata_processed.obs['fate_map_clonal_transition_map_Reprogrammed'] + adata_processed.obs['fate_map_clonal_transition_map_Failed'])

x0_adata = adata_processed[~np.isnan(adata_processed.obs['Cospar_fate_bias'])]
x0_adata = x0_adata[x0_adata.obs['benchmark']]

groundtruth_key = 'Cospar_fate_bias'
# Out:
# WARNING: Pre-computed time_ordering does not include the right time points. Re-compute it!
# Infer transition map between neighboring time points.
# --> Clonal cell fraction (day Day15-Day21): 0.805352798053528
# --> Clonal cell fraction (day Day21-Day28): 0.8049918831168831
# --> Clonal cell fraction (day Day21-Day15): 0.8952922077922078
# --> Clonal cell fraction (day Day28-Day21): 0.9663468859448759
# --> Numer of cells that are clonally related -- day Day15: 2648  and day Day21: 4412
# --> Numer of cells that are clonally related -- day Day21: 3967  and day Day28: 6346
# Number of multi-time clones post selection: 440
# Cell number=14783, Clone number=440
# --> clonal_cell_id_t1: 6615
# --> Tmap_cell_id_t1: 8216
# Use all clones (naive method)
# Use all clones (naive method)
# Results saved at adata.obs['fate_map_clonal_transition_map_Reprogrammed']
# Results saved at adata.obs['fate_map_clonal_transition_map_Failed']

# %%
sc.pl.embedding(x0_adata, color=groundtruth_key, basis='emb', cmap='coolwarm')

# %% [markdown]
# ## Training model

# %% [markdown]
# ### GOT

# %%
#gots = []
#for i in range(10):
#    model, _ = pygot.tl.traj.fit_velocity_model(adata, time_key=time_key, embedding_key=embedding_key, path='./benchmark_model/GOT/03_cell_fate/reprogramming_fate/', 
#                                       device=device, x_centric_iter_n=3000, time_varying=True)
#    gots.append(model)

#for i, got in enumerate(gots):
#    os.system('mkdir ./benchmark_model/GOT/03_cell_fate/reprogramming_fate/'+str(i))
#    torch.save(got, './benchmark_model/GOT/03_cell_fate/reprogramming_fate/'+str(i)+'/got.pkl')
# Out:
# loading saved shortest path profile
# [Errno 2] No such file or directory: './benchmark_model/GOT/03_cell_fate/reprogramming_fate/pc30//_0to1.pkl'
# Error in loading shortest path file
# calcu shortest path between 0 to 1
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3288/3288 [00:12<00:00, 272.11it/s]
# calcu shortest path between 1 to 2
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4928/4928 [00:27<00:00, 181.00it/s]
# loss :16.5222 best :16.3896: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:13<00:00, 13.61it/s]
# loss :140.6717  best :140.6717: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:11<00:00, 42.25it/s]
# loading saved shortest path profile
# loss :16.3514 best :16.1866: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:10<00:00, 14.14it/s]
# loss :142.0304  best :142.0304: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:11<00:00, 42.16it/s]
# loading saved shortest path profile
# loss :16.3423 best :16.2413: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:08<00:00, 14.55it/s]
# loss :144.5781  best :144.1008: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:10<00:00, 42.76it/s]
# loading saved shortest path profile
# loss :16.2439 best :16.1348: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:09<00:00, 14.31it/s]
# loss :142.5624  best :141.3395: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:10<00:00, 42.78it/s]
# loading saved shortest path profile
# loss :16.2469 best :16.2469: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:25<00:00, 11.76it/s]
# loss :142.6977  best :142.2942: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:15<00:00, 39.59it/s]
# loading saved shortest path profile
# loss :16.4376 best :16.2917: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:13<00:00, 13.65it/s]
# loss :144.2502  best :142.0379: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:12<00:00, 41.53it/s]
# loading saved shortest path profile
# loss :16.2253 best :16.2253: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:19<00:00, 12.50it/s]
# loss :143.2506  best :142.0833: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:10<00:00, 42.28it/s]
# loading saved shortest path profile
# loss :16.4093 best :16.1517: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:09<00:00, 14.30it/s]
# loss :145.2112  best :141.7364: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:13<00:00, 40.70it/s]
# loading saved shortest path profile
# loss :16.5322 best :16.4259: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:19<00:00, 12.66it/s]
# loss :141.6470  best :140.0628: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:15<00:00, 39.95it/s]
# loading saved shortest path profile
# loss :16.3445 best :16.2842: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:23<00:00, 11.91it/s]
# loss :141.5733  best :141.4284: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:14<00:00, 40.52it/s]

# %%
gots = []
for i in range(10):
    gots.append(torch.load( './benchmark_model/GOT/03_cell_fate/reprogramming_fate/'+str(i)+'/got.pkl'))

# %% [markdown]
# ### CoSpar

# %%
def generate_clone_matrix(adata, clone_key):
    
    all_clone = adata.obs[clone_key][adata.obs[clone_key] == adata.obs[clone_key]].unique()
    
    X_clone = np.zeros((len(adata), len(all_clone)))
    adata.obs['idx'] = range(len(adata))
    for i, clone in enumerate(all_clone):
        j = adata.obs.loc[adata.obs[clone_key] == clone]['idx'].tolist()
        X_clone[j, i] = 1
    adata.obsm['X_clone'] = X_clone

# %%
for e in range(10):
    adata_orig = adata.copy()
    generate_clone_matrix(adata_orig, 'clone')
    selected_clone = np.random.choice(range(adata_orig.obsm['X_clone'].shape[1]), size=int(0.5 * adata_orig.obsm['X_clone'].shape[1]), replace=False)
    adata_orig.obsm['X_clone'] = adata_orig.obsm['X_clone'][:,selected_clone]
    adata_orig = cs.pp.initialize_adata_object(adata_orig, time_info=adata_orig.obs[time_key], state_info=adata_orig.obs[cell_type_key])
    
    adata_lineage = cs.tmap.infer_Tmap_from_multitime_clones(
            adata_orig,
            clonal_time_points=["0", "1", "2"],
            later_time_point="2",
            smooth_array=[15, 10, 5],
            sparsity_threshold=0.2,
            intraclone_threshold=0.2,
            compute_new=True
                
    )
    cs.tl.fate_bias(
            adata_lineage,
            selected_fates=["Reprogrammed", "Failed"],
            source="transition_map",
            map_backward=True,
            method="norm-sum",
    )
    
    adata_lineage.obs.to_csv('../pygot_data/03_cellfate/reprogram/cospar_{}.csv'.format(e))
# Out:
# Time points with clonal info: ['0' '1' '2']
# WARNING: Default ascending order of time points are: ['0' '1' '2']. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.020899295806884766
# Smooth round: 2
# --> Time elapsed: 0.18776965141296387
# Smooth round: 3
# --> Time elapsed: 1.3673393726348877
# --> Orignal sparsity=0.13952742364935591, Thresholding
# --> Final sparsity=0.08274391355144298
# similarity matrix truncated (Smooth round=3):  1.7702076435089111
# Smooth round: 4
# --> Time elapsed: 3.6408848762512207
# --> Orignal sparsity=0.27102499292465637, Thresholding
# --> Final sparsity=0.14234637306805162
# similarity matrix truncated (Smooth round=4):  2.2865638732910156
# Smooth round: 5
# --> Time elapsed: 4.668622970581055
# --> Orignal sparsity=0.3675729065833763, Thresholding
# --> Final sparsity=0.2031454486885748
# similarity matrix truncated (Smooth round=5):  1.9637272357940674
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 6.442291498184204
# --> Orignal sparsity=0.44981876737636967, Thresholding
# --> Final sparsity=0.2630086053722442
# similarity matrix truncated (Smooth round=6):  2.0077857971191406
# Smooth round: 7
# --> Time elapsed: 7.757828712463379
# --> Orignal sparsity=0.5215356419431395, Thresholding
# --> Final sparsity=0.3217560750065633
# similarity matrix truncated (Smooth round=7):  2.3665099143981934
# Smooth round: 8
# --> Time elapsed: 8.577640533447266
# --> Orignal sparsity=0.585094011204661, Thresholding
# --> Final sparsity=0.3777265103041617
# similarity matrix truncated (Smooth round=8):  2.5827486515045166
# Smooth round: 9
# --> Time elapsed: 9.875340938568115
# --> Orignal sparsity=0.6402611457865626, Thresholding
# --> Final sparsity=0.43029325791010237
# similarity matrix truncated (Smooth round=9):  2.1425116062164307
# Smooth round: 10
# --> Time elapsed: 10.942351579666138
# --> Orignal sparsity=0.687911185638608, Thresholding
# --> Final sparsity=0.47912752695264466
# similarity matrix truncated (Smooth round=10):  2.043344259262085
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 12.100262880325317
# --> Orignal sparsity=0.7287457141885879, Thresholding
# --> Final sparsity=0.5242171776160156
# similarity matrix truncated (Smooth round=11):  2.124767541885376
# Smooth round: 12
# --> Time elapsed: 13.130314111709595
# --> Orignal sparsity=0.7637607362839907, Thresholding
# --> Final sparsity=0.5656756277191923
# similarity matrix truncated (Smooth round=12):  2.078469753265381
# Smooth round: 13
# --> Time elapsed: 14.128279685974121
# --> Orignal sparsity=0.7937350853977926, Thresholding
# --> Final sparsity=0.6037475222340863
# similarity matrix truncated (Smooth round=13):  2.2135820388793945
# Smooth round: 14
# --> Time elapsed: 15.1678626537323
# --> Orignal sparsity=0.8195896166622774, Thresholding
# --> Final sparsity=0.6386823382643301
# similarity matrix truncated (Smooth round=14):  2.417348623275757
# Smooth round: 15
# --> Time elapsed: 15.718199968338013
# --> Orignal sparsity=0.8419925873543598, Thresholding
# --> Final sparsity=0.6706816891845759
# similarity matrix truncated (Smooth round=15):  2.0208938121795654
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-2): 0.27463503649635035
# --> Clonal cell fraction (day 2-0): 0.42667884878940154
# --> Numer of cells that are clonally related -- day 0: 903  and day 2: 2802
# Number of multi-time clones post selection: 91
# Cell number=9855, Clone number=91
# --> clonal_cell_id_t1: 903
# --> Tmap_cell_id_t1: 3288
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.011716127395629883
# --> Time elapsed:  0.17368745803833008
# --> Time elapsed:  0.045794010162353516
# --> Time elapsed:  0.2271876335144043
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.012932538986206055
# --> Time elapsed:  0.2167973518371582
# --> Time elapsed:  0.04700922966003418
# --> Time elapsed:  0.22398614883422852
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.015063047409057617
# --> Time elapsed:  0.14565634727478027
# --> Time elapsed:  0.04541516304016113
# --> Time elapsed:  0.14507436752319336
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.25740981101989746
# --> Phase II: time elapsed --  0.26897621154785156
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.07867765426635742
# --> Phase II: time elapsed --  0.08804750442504883
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.030606508255004883
# --> Phase II: time elapsed --  0.036704301834106445
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.023656368255615234
# --> Phase II: time elapsed --  0.029567956924438477
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.1370096206665039
# --> Phase II: time elapsed --  0.1865065097808838
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-2): 0.38818993506493504
# --> Clonal cell fraction (day 2-1): 0.455459113750571
# --> Numer of cells that are clonally related -- day 1: 1913  and day 2: 2991
# Number of multi-time clones post selection: 115
# Cell number=11495, Clone number=115
# --> clonal_cell_id_t1: 1913
# --> Tmap_cell_id_t1: 4928
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.05614638328552246
# --> Time elapsed:  0.3133254051208496
# --> Time elapsed:  0.157684326171875
# --> Time elapsed:  0.3461439609527588
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.05180549621582031
# --> Time elapsed:  0.2823982238769531
# --> Time elapsed:  0.14565038681030273
# --> Time elapsed:  0.32434940338134766
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.04146218299865723
# --> Time elapsed:  0.1655125617980957
# --> Time elapsed:  0.09595966339111328
# --> Time elapsed:  0.18953609466552734
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  1.570939302444458
# --> Phase II: time elapsed --  1.5894901752471924
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.31970953941345215
# --> Phase II: time elapsed --  0.3398463726043701
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.20529770851135254
# --> Phase II: time elapsed --  0.22565579414367676
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.11733794212341309
# --> Phase II: time elapsed --  0.13605952262878418
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.28794097900390625
# --> Phase II: time elapsed --  0.36867856979370117
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 371.22292613983154 s ------------
# Results saved at adata.obs['fate_map_transition_map_Reprogrammed']
# Results saved at adata.obs['fate_map_transition_map_Failed']
# Results saved at adata.obs['fate_bias_transition_map_Reprogrammed*Failed']
# Time points with clonal info: ['0' '1' '2']
# WARNING: Default ascending order of time points are: ['0' '1' '2']. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.021260499954223633
# Smooth round: 2
# --> Time elapsed: 0.20299983024597168
# Smooth round: 3
# --> Time elapsed: 1.5070655345916748
# --> Orignal sparsity=0.13952742364935591, Thresholding
# --> Final sparsity=0.08274391355144298
# similarity matrix truncated (Smooth round=3):  1.921485185623169
# Smooth round: 4
# --> Time elapsed: 3.2959275245666504
# --> Orignal sparsity=0.27102499292465637, Thresholding
# --> Final sparsity=0.14234637306805162
# similarity matrix truncated (Smooth round=4):  1.8750009536743164
# Smooth round: 5
# --> Time elapsed: 4.671557664871216
# --> Orignal sparsity=0.3675729065833763, Thresholding
# --> Final sparsity=0.2031454486885748
# similarity matrix truncated (Smooth round=5):  2.079096794128418
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 6.209036588668823
# --> Orignal sparsity=0.44981876737636967, Thresholding
# --> Final sparsity=0.2630086053722442
# similarity matrix truncated (Smooth round=6):  1.9833457469940186
# Smooth round: 7
# --> Time elapsed: 7.839463233947754
# --> Orignal sparsity=0.5215356419431395, Thresholding
# --> Final sparsity=0.3217560750065633
# similarity matrix truncated (Smooth round=7):  2.1944291591644287
# Smooth round: 8
# --> Time elapsed: 8.874332904815674
# --> Orignal sparsity=0.585094011204661, Thresholding
# --> Final sparsity=0.3777265103041617
# similarity matrix truncated (Smooth round=8):  2.264173984527588
# Smooth round: 9
# --> Time elapsed: 9.655723810195923
# --> Orignal sparsity=0.6402611457865626, Thresholding
# --> Final sparsity=0.43029325791010237
# similarity matrix truncated (Smooth round=9):  2.3115527629852295
# Smooth round: 10
# --> Time elapsed: 10.94539189338684
# --> Orignal sparsity=0.687911185638608, Thresholding
# --> Final sparsity=0.47912752695264466
# similarity matrix truncated (Smooth round=10):  2.335069179534912
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 12.287718772888184
# --> Orignal sparsity=0.7287457141885879, Thresholding
# --> Final sparsity=0.5242171776160156
# similarity matrix truncated (Smooth round=11):  2.0821657180786133
# Smooth round: 12
# --> Time elapsed: 12.89418077468872
# --> Orignal sparsity=0.7637607362839907, Thresholding
# --> Final sparsity=0.5656756277191923
# similarity matrix truncated (Smooth round=12):  2.138564348220825
# Smooth round: 13
# --> Time elapsed: 13.964271068572998
# --> Orignal sparsity=0.7937350853977926, Thresholding
# --> Final sparsity=0.6037475222340863
# similarity matrix truncated (Smooth round=13):  2.30027174949646
# Smooth round: 14
# --> Time elapsed: 14.76267671585083
# --> Orignal sparsity=0.8195896166622774, Thresholding
# --> Final sparsity=0.6386823382643301
# similarity matrix truncated (Smooth round=14):  2.3544111251831055
# Smooth round: 15
# --> Time elapsed: 15.437884330749512
# --> Orignal sparsity=0.8419925873543598, Thresholding
# --> Final sparsity=0.6706816891845759
# similarity matrix truncated (Smooth round=15):  2.0030767917633057
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-2): 0.2731143552311436
# --> Clonal cell fraction (day 2-0): 0.3788640170549718
# --> Numer of cells that are clonally related -- day 0: 898  and day 2: 2488
# Number of multi-time clones post selection: 82
# Cell number=9855, Clone number=82
# --> clonal_cell_id_t1: 898
# --> Tmap_cell_id_t1: 3288
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.011478900909423828
# --> Time elapsed:  0.1607532501220703
# --> Time elapsed:  0.04650759696960449
# --> Time elapsed:  0.20771408081054688
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.011228799819946289
# --> Time elapsed:  0.15777230262756348
# --> Time elapsed:  0.04509305953979492
# --> Time elapsed:  0.20692110061645508
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.012118816375732422
# --> Time elapsed:  0.10073471069335938
# --> Time elapsed:  0.05105113983154297
# --> Time elapsed:  0.14887523651123047
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.1427147388458252
# --> Phase II: time elapsed --  0.14788198471069336
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.02988886833190918
# --> Phase II: time elapsed --  0.03796243667602539
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.02650928497314453
# --> Phase II: time elapsed --  0.03703594207763672
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.02436685562133789
# --> Phase II: time elapsed --  0.030878067016601562
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.13306903839111328
# --> Phase II: time elapsed --  0.1704721450805664
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-2): 0.385349025974026
# --> Clonal cell fraction (day 2-1): 0.40794883508451346
# --> Numer of cells that are clonally related -- day 1: 1899  and day 2: 2679
# Number of multi-time clones post selection: 103
# Cell number=11495, Clone number=103
# --> clonal_cell_id_t1: 1899
# --> Tmap_cell_id_t1: 4928
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.0585024356842041
# --> Time elapsed:  0.26328492164611816
# --> Time elapsed:  0.15511560440063477
# --> Time elapsed:  0.29925084114074707
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.08173489570617676
# --> Time elapsed:  0.25109338760375977
# --> Time elapsed:  0.17682433128356934
# --> Time elapsed:  0.30709218978881836
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.03136038780212402
# --> Time elapsed:  0.13728547096252441
# --> Time elapsed:  0.11866044998168945
# --> Time elapsed:  0.17098450660705566
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  1.213719367980957
# --> Phase II: time elapsed --  1.2290339469909668
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.3074665069580078
# --> Phase II: time elapsed --  0.32458019256591797
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.20563626289367676
# --> Phase II: time elapsed --  0.22256231307983398
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.10780096054077148
# --> Phase II: time elapsed --  0.12359237670898438
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.31673288345336914
# --> Phase II: time elapsed --  0.3980288505554199
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 368.0836088657379 s ------------
# Results saved at adata.obs['fate_map_transition_map_Reprogrammed']
# Results saved at adata.obs['fate_map_transition_map_Failed']
# Results saved at adata.obs['fate_bias_transition_map_Reprogrammed*Failed']
# Time points with clonal info: ['0' '1' '2']
# WARNING: Default ascending order of time points are: ['0' '1' '2']. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.021873950958251953
# Smooth round: 2
# --> Time elapsed: 0.18967056274414062
# Smooth round: 3
# --> Time elapsed: 1.4866046905517578
# --> Orignal sparsity=0.13952742364935591, Thresholding
# --> Final sparsity=0.08274391355144298
# similarity matrix truncated (Smooth round=3):  2.0304625034332275
# Smooth round: 4
# --> Time elapsed: 3.2608683109283447
# --> Orignal sparsity=0.27102499292465637, Thresholding
# --> Final sparsity=0.14234637306805162
# similarity matrix truncated (Smooth round=4):  1.941112995147705
# Smooth round: 5
# --> Time elapsed: 4.677586078643799
# --> Orignal sparsity=0.3675729065833763, Thresholding
# --> Final sparsity=0.2031454486885748
# similarity matrix truncated (Smooth round=5):  2.15559983253479
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 6.207042932510376
# --> Orignal sparsity=0.44981876737636967, Thresholding
# --> Final sparsity=0.2630086053722442
# similarity matrix truncated (Smooth round=6):  2.0130410194396973
# Smooth round: 7
# --> Time elapsed: 7.8089494705200195
# --> Orignal sparsity=0.5215356419431395, Thresholding
# --> Final sparsity=0.3217560750065633
# similarity matrix truncated (Smooth round=7):  2.1703312397003174
# Smooth round: 8
# --> Time elapsed: 8.84027886390686
# --> Orignal sparsity=0.585094011204661, Thresholding
# --> Final sparsity=0.3777265103041617
# similarity matrix truncated (Smooth round=8):  2.365432024002075
# Smooth round: 9
# --> Time elapsed: 9.755718231201172
# --> Orignal sparsity=0.6402611457865626, Thresholding
# --> Final sparsity=0.43029325791010237
# similarity matrix truncated (Smooth round=9):  2.725036144256592
# Smooth round: 10
# --> Time elapsed: 11.339478969573975
# --> Orignal sparsity=0.687911185638608, Thresholding
# --> Final sparsity=0.47912752695264466
# similarity matrix truncated (Smooth round=10):  2.6519460678100586
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 12.703259229660034
# --> Orignal sparsity=0.7287457141885879, Thresholding
# --> Final sparsity=0.5242171776160156
# similarity matrix truncated (Smooth round=11):  3.180664300918579
# Smooth round: 12
# --> Time elapsed: 12.104338645935059
# --> Orignal sparsity=0.7637607362839907, Thresholding
# --> Final sparsity=0.5656756277191923
# similarity matrix truncated (Smooth round=12):  2.0814998149871826
# Smooth round: 13
# --> Time elapsed: 12.780863285064697
# --> Orignal sparsity=0.7937350853977926, Thresholding
# --> Final sparsity=0.6037475222340863
# similarity matrix truncated (Smooth round=13):  2.061356544494629
# Smooth round: 14
# --> Time elapsed: 13.381055355072021
# --> Orignal sparsity=0.8195896166622774, Thresholding
# --> Final sparsity=0.6386823382643301
# similarity matrix truncated (Smooth round=14):  2.0553412437438965
# Smooth round: 15
# --> Time elapsed: 13.907927513122559
# --> Orignal sparsity=0.8419925873543598, Thresholding
# --> Final sparsity=0.6706816891845759
# similarity matrix truncated (Smooth round=15):  2.0347790718078613
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-2): 0.23905109489051096
# --> Clonal cell fraction (day 2-0): 0.41906502208009744
# --> Numer of cells that are clonally related -- day 0: 786  and day 2: 2752
# Number of multi-time clones post selection: 79
# Cell number=9855, Clone number=79
# --> clonal_cell_id_t1: 786
# --> Tmap_cell_id_t1: 3288
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.009925603866577148
# --> Time elapsed:  0.17721962928771973
# --> Time elapsed:  0.046339988708496094
# --> Time elapsed:  0.22838711738586426
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.00924825668334961
# --> Time elapsed:  0.17622113227844238
# --> Time elapsed:  0.04119443893432617
# --> Time elapsed:  0.21430063247680664
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.008773088455200195
# --> Time elapsed:  0.10960865020751953
# --> Time elapsed:  0.03613615036010742
# --> Time elapsed:  0.1369152069091797
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.22533226013183594
# --> Phase II: time elapsed --  0.23018622398376465
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.03610944747924805
# --> Phase II: time elapsed --  0.042276620864868164
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.025716066360473633
# --> Phase II: time elapsed --  0.03144121170043945
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.021410226821899414
# --> Phase II: time elapsed --  0.026824951171875
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.09044551849365234
# --> Phase II: time elapsed --  0.12476801872253418
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-2): 0.3216314935064935
# --> Clonal cell fraction (day 2-1): 0.455459113750571
# --> Numer of cells that are clonally related -- day 1: 1585  and day 2: 2991
# Number of multi-time clones post selection: 109
# Cell number=11495, Clone number=109
# --> clonal_cell_id_t1: 1585
# --> Tmap_cell_id_t1: 4928
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.0449223518371582
# --> Time elapsed:  0.3049492835998535
# --> Time elapsed:  0.14566349983215332
# --> Time elapsed:  0.33568668365478516
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.04036116600036621
# --> Time elapsed:  0.27802515029907227
# --> Time elapsed:  0.1338202953338623
# --> Time elapsed:  0.3046860694885254
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.024111032485961914
# --> Time elapsed:  0.15005111694335938
# --> Time elapsed:  0.08343291282653809
# --> Time elapsed:  0.17711210250854492
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.6409664154052734
# --> Phase II: time elapsed --  0.6537160873413086
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.13007330894470215
# --> Phase II: time elapsed --  0.14275860786437988
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.08913564682006836
# --> Phase II: time elapsed --  0.10158276557922363
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.06635093688964844
# --> Phase II: time elapsed --  0.08130359649658203
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.16368818283081055
# --> Phase II: time elapsed --  0.23954129219055176
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 364.17526268959045 s ------------
# Results saved at adata.obs['fate_map_transition_map_Reprogrammed']
# Results saved at adata.obs['fate_map_transition_map_Failed']
# Results saved at adata.obs['fate_bias_transition_map_Reprogrammed*Failed']
# Time points with clonal info: ['0' '1' '2']
# WARNING: Default ascending order of time points are: ['0' '1' '2']. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.022135019302368164
# Smooth round: 2
# --> Time elapsed: 0.18793535232543945
# Smooth round: 3
# --> Time elapsed: 1.3645517826080322
# --> Orignal sparsity=0.13952742364935591, Thresholding
# --> Final sparsity=0.08274391355144298
# similarity matrix truncated (Smooth round=3):  1.778066635131836
# Smooth round: 4
# --> Time elapsed: 3.134427547454834
# --> Orignal sparsity=0.27102499292465637, Thresholding
# --> Final sparsity=0.14234637306805162
# similarity matrix truncated (Smooth round=4):  1.8953664302825928
# Smooth round: 5
# --> Time elapsed: 4.6483423709869385
# --> Orignal sparsity=0.3675729065833763, Thresholding
# --> Final sparsity=0.2031454486885748
# similarity matrix truncated (Smooth round=5):  1.9781591892242432
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 6.046901226043701
# --> Orignal sparsity=0.44981876737636967, Thresholding
# --> Final sparsity=0.2630086053722442
# similarity matrix truncated (Smooth round=6):  2.0096585750579834
# Smooth round: 7
# --> Time elapsed: 7.324281692504883
# --> Orignal sparsity=0.5215356419431395, Thresholding
# --> Final sparsity=0.3217560750065633
# similarity matrix truncated (Smooth round=7):  2.0450384616851807
# Smooth round: 8
# --> Time elapsed: 8.494555473327637
# --> Orignal sparsity=0.585094011204661, Thresholding
# --> Final sparsity=0.3777265103041617
# similarity matrix truncated (Smooth round=8):  2.06628680229187
# Smooth round: 9
# --> Time elapsed: 9.559321880340576
# --> Orignal sparsity=0.6402611457865626, Thresholding
# --> Final sparsity=0.43029325791010237
# similarity matrix truncated (Smooth round=9):  2.073500156402588
# Smooth round: 10
# --> Time elapsed: 10.529422521591187
# --> Orignal sparsity=0.687911185638608, Thresholding
# --> Final sparsity=0.47912752695264466
# similarity matrix truncated (Smooth round=10):  2.072798013687134
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 11.376657724380493
# --> Orignal sparsity=0.7287457141885879, Thresholding
# --> Final sparsity=0.5242171776160156
# similarity matrix truncated (Smooth round=11):  2.0661628246307373
# Smooth round: 12
# --> Time elapsed: 12.134953737258911
# --> Orignal sparsity=0.7637607362839907, Thresholding
# --> Final sparsity=0.5656756277191923
# similarity matrix truncated (Smooth round=12):  2.052863359451294
# Smooth round: 13
# --> Time elapsed: 12.813543558120728
# --> Orignal sparsity=0.7937350853977926, Thresholding
# --> Final sparsity=0.6037475222340863
# similarity matrix truncated (Smooth round=13):  2.0358355045318604
# Smooth round: 14
# --> Time elapsed: 13.398752212524414
# --> Orignal sparsity=0.8195896166622774, Thresholding
# --> Final sparsity=0.6386823382643301
# similarity matrix truncated (Smooth round=14):  2.0193629264831543
# Smooth round: 15
# --> Time elapsed: 13.921043395996094
# --> Orignal sparsity=0.8419925873543598, Thresholding
# --> Final sparsity=0.6706816891845759
# similarity matrix truncated (Smooth round=15):  1.9965622425079346
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-2): 0.29683698296836986
# --> Clonal cell fraction (day 2-0): 0.6584437338206183
# --> Numer of cells that are clonally related -- day 0: 976  and day 2: 4324
# Number of multi-time clones post selection: 96
# Cell number=9855, Clone number=96
# --> clonal_cell_id_t1: 976
# --> Tmap_cell_id_t1: 3288
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.013098478317260742
# --> Time elapsed:  0.26191067695617676
# --> Time elapsed:  0.04613971710205078
# --> Time elapsed:  0.29243898391723633
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.011932373046875
# --> Time elapsed:  0.23780465126037598
# --> Time elapsed:  0.04223918914794922
# --> Time elapsed:  0.2640514373779297
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.011983633041381836
# --> Time elapsed:  0.1519160270690918
# --> Time elapsed:  0.04039812088012695
# --> Time elapsed:  0.1750035285949707
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.7407448291778564
# --> Phase II: time elapsed --  0.7527604103088379
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.13888192176818848
# --> Phase II: time elapsed --  0.14878296852111816
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.09565019607543945
# --> Phase II: time elapsed --  0.10580110549926758
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.07430171966552734
# --> Phase II: time elapsed --  0.0852057933807373
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.12957549095153809
# --> Phase II: time elapsed --  0.17524337768554688
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-2): 0.43445616883116883
# --> Clonal cell fraction (day 2-1): 0.6814374904827166
# --> Numer of cells that are clonally related -- day 1: 2141  and day 2: 4475
# Number of multi-time clones post selection: 117
# Cell number=11495, Clone number=117
# --> clonal_cell_id_t1: 2141
# --> Tmap_cell_id_t1: 4928
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.07731819152832031
# --> Time elapsed:  0.3845219612121582
# --> Time elapsed:  0.16979146003723145
# --> Time elapsed:  0.41408467292785645
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.07041668891906738
# --> Time elapsed:  0.3369574546813965
# --> Time elapsed:  0.15045714378356934
# --> Time elapsed:  0.3720102310180664
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.044587135314941406
# --> Time elapsed:  0.1835768222808838
# --> Time elapsed:  0.09561967849731445
# --> Time elapsed:  0.2047262191772461
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  3.461949586868286
# --> Phase II: time elapsed --  3.491539716720581
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.6912751197814941
# --> Phase II: time elapsed --  0.720761775970459
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.41395139694213867
# --> Phase II: time elapsed --  0.442859411239624
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.18391156196594238
# --> Phase II: time elapsed --  0.21288728713989258
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.28009748458862305
# --> Phase II: time elapsed --  0.3689401149749756
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 368.19471406936646 s ------------
# Results saved at adata.obs['fate_map_transition_map_Reprogrammed']
# Results saved at adata.obs['fate_map_transition_map_Failed']
# Results saved at adata.obs['fate_bias_transition_map_Reprogrammed*Failed']
# Time points with clonal info: ['0' '1' '2']
# WARNING: Default ascending order of time points are: ['0' '1' '2']. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.022933006286621094
# Smooth round: 2
# --> Time elapsed: 0.18474888801574707
# Smooth round: 3
# --> Time elapsed: 1.3690416812896729
# --> Orignal sparsity=0.13952742364935591, Thresholding
# --> Final sparsity=0.08274391355144298
# similarity matrix truncated (Smooth round=3):  1.7765319347381592
# Smooth round: 4
# --> Time elapsed: 3.133556365966797
# --> Orignal sparsity=0.27102499292465637, Thresholding
# --> Final sparsity=0.14234637306805162
# similarity matrix truncated (Smooth round=4):  1.8939859867095947
# Smooth round: 5
# --> Time elapsed: 4.649253606796265
# --> Orignal sparsity=0.3675729065833763, Thresholding
# --> Final sparsity=0.2031454486885748
# similarity matrix truncated (Smooth round=5):  1.9615299701690674
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 6.0413498878479
# --> Orignal sparsity=0.44981876737636967, Thresholding
# --> Final sparsity=0.2630086053722442
# similarity matrix truncated (Smooth round=6):  2.0075037479400635
# Smooth round: 7
# --> Time elapsed: 7.3299560546875
# --> Orignal sparsity=0.5215356419431395, Thresholding
# --> Final sparsity=0.3217560750065633
# similarity matrix truncated (Smooth round=7):  2.034140110015869
# Smooth round: 8
# --> Time elapsed: 8.49498462677002
# --> Orignal sparsity=0.585094011204661, Thresholding
# --> Final sparsity=0.3777265103041617
# similarity matrix truncated (Smooth round=8):  2.058716058731079
# Smooth round: 9
# --> Time elapsed: 9.563486337661743
# --> Orignal sparsity=0.6402611457865626, Thresholding
# --> Final sparsity=0.43029325791010237
# similarity matrix truncated (Smooth round=9):  2.0753743648529053
# Smooth round: 10
# --> Time elapsed: 10.528959512710571
# --> Orignal sparsity=0.687911185638608, Thresholding
# --> Final sparsity=0.47912752695264466
# similarity matrix truncated (Smooth round=10):  2.075716018676758
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 11.36125373840332
# --> Orignal sparsity=0.7287457141885879, Thresholding
# --> Final sparsity=0.5242171776160156
# similarity matrix truncated (Smooth round=11):  2.0634114742279053
# Smooth round: 12
# --> Time elapsed: 12.118825674057007
# --> Orignal sparsity=0.7637607362839907, Thresholding
# --> Final sparsity=0.5656756277191923
# similarity matrix truncated (Smooth round=12):  2.0510857105255127
# Smooth round: 13
# --> Time elapsed: 12.887378454208374
# --> Orignal sparsity=0.7937350853977926, Thresholding
# --> Final sparsity=0.6037475222340863
# similarity matrix truncated (Smooth round=13):  2.065436840057373
# Smooth round: 14
# --> Time elapsed: 13.421283483505249
# --> Orignal sparsity=0.8195896166622774, Thresholding
# --> Final sparsity=0.6386823382643301
# similarity matrix truncated (Smooth round=14):  2.015773296356201
# Smooth round: 15
# --> Time elapsed: 13.929732084274292
# --> Orignal sparsity=0.8419925873543598, Thresholding
# --> Final sparsity=0.6706816891845759
# similarity matrix truncated (Smooth round=15):  1.9966394901275635
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-2): 0.2846715328467153
# --> Clonal cell fraction (day 2-0): 0.4560682198873154
# --> Numer of cells that are clonally related -- day 0: 936  and day 2: 2995
# Number of multi-time clones post selection: 89
# Cell number=9855, Clone number=89
# --> clonal_cell_id_t1: 936
# --> Tmap_cell_id_t1: 3288
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.01180410385131836
# --> Time elapsed:  0.18422603607177734
# --> Time elapsed:  0.04779338836669922
# --> Time elapsed:  0.23971819877624512
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.011861324310302734
# --> Time elapsed:  0.18246030807495117
# --> Time elapsed:  0.04473519325256348
# --> Time elapsed:  0.21926021575927734
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.011969804763793945
# --> Time elapsed:  0.1119685173034668
# --> Time elapsed:  0.040130615234375
# --> Time elapsed:  0.1393418312072754
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.2978942394256592
# --> Phase II: time elapsed --  0.3042936325073242
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.06085562705993652
# --> Phase II: time elapsed --  0.06733369827270508
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.04396343231201172
# --> Phase II: time elapsed --  0.050338029861450195
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.0329132080078125
# --> Phase II: time elapsed --  0.03957772254943848
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.09537100791931152
# --> Phase II: time elapsed --  0.13141274452209473
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-2): 0.36160714285714285
# --> Clonal cell fraction (day 2-1): 0.48911222780569513
# --> Numer of cells that are clonally related -- day 1: 1782  and day 2: 3212
# Number of multi-time clones post selection: 108
# Cell number=11495, Clone number=108
# --> clonal_cell_id_t1: 1782
# --> Tmap_cell_id_t1: 4928
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.05597043037414551
# --> Time elapsed:  0.3084728717803955
# --> Time elapsed:  0.15488123893737793
# --> Time elapsed:  0.3531191349029541
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.04561567306518555
# --> Time elapsed:  0.28510212898254395
# --> Time elapsed:  0.13939213752746582
# --> Time elapsed:  0.31663942337036133
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.028075218200683594
# --> Time elapsed:  0.15159225463867188
# --> Time elapsed:  0.0887446403503418
# --> Time elapsed:  0.17697906494140625
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.7499048709869385
# --> Phase II: time elapsed --  0.7660179138183594
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.1327822208404541
# --> Phase II: time elapsed --  0.14882445335388184
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.09473061561584473
# --> Phase II: time elapsed --  0.11054468154907227
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.05444622039794922
# --> Phase II: time elapsed --  0.07047295570373535
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.14641737937927246
# --> Phase II: time elapsed --  0.22324442863464355
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 355.2428512573242 s ------------
# Results saved at adata.obs['fate_map_transition_map_Reprogrammed']
# Results saved at adata.obs['fate_map_transition_map_Failed']
# Results saved at adata.obs['fate_bias_transition_map_Reprogrammed*Failed']
# Time points with clonal info: ['0' '1' '2']
# WARNING: Default ascending order of time points are: ['0' '1' '2']. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.02341747283935547
# Smooth round: 2
# --> Time elapsed: 0.187697172164917
# Smooth round: 3
# --> Time elapsed: 1.3693251609802246
# --> Orignal sparsity=0.13952742364935591, Thresholding
# --> Final sparsity=0.08274391355144298
# similarity matrix truncated (Smooth round=3):  1.7763361930847168
# Smooth round: 4
# --> Time elapsed: 3.1296050548553467
# --> Orignal sparsity=0.27102499292465637, Thresholding
# --> Final sparsity=0.14234637306805162
# similarity matrix truncated (Smooth round=4):  1.8840546607971191
# Smooth round: 5
# --> Time elapsed: 4.6523377895355225
# --> Orignal sparsity=0.3675729065833763, Thresholding
# --> Final sparsity=0.2031454486885748
# similarity matrix truncated (Smooth round=5):  1.9606194496154785
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 6.04559588432312
# --> Orignal sparsity=0.44981876737636967, Thresholding
# --> Final sparsity=0.2630086053722442
# similarity matrix truncated (Smooth round=6):  2.0114479064941406
# Smooth round: 7
# --> Time elapsed: 7.315632104873657
# --> Orignal sparsity=0.5215356419431395, Thresholding
# --> Final sparsity=0.3217560750065633
# similarity matrix truncated (Smooth round=7):  2.008444309234619
# Smooth round: 8
# --> Time elapsed: 8.499775409698486
# --> Orignal sparsity=0.585094011204661, Thresholding
# --> Final sparsity=0.3777265103041617
# similarity matrix truncated (Smooth round=8):  2.0378334522247314
# Smooth round: 9
# --> Time elapsed: 10.240376710891724
# --> Orignal sparsity=0.6402611457865626, Thresholding
# --> Final sparsity=0.43029325791010237
# similarity matrix truncated (Smooth round=9):  2.1422228813171387
# Smooth round: 10
# --> Time elapsed: 11.197099208831787
# --> Orignal sparsity=0.687911185638608, Thresholding
# --> Final sparsity=0.47912752695264466
# similarity matrix truncated (Smooth round=10):  2.069857358932495
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 11.374737739562988
# --> Orignal sparsity=0.7287457141885879, Thresholding
# --> Final sparsity=0.5242171776160156
# similarity matrix truncated (Smooth round=11):  2.0482418537139893
# Smooth round: 12
# --> Time elapsed: 12.149906873703003
# --> Orignal sparsity=0.7637607362839907, Thresholding
# --> Final sparsity=0.5656756277191923
# similarity matrix truncated (Smooth round=12):  2.101569414138794
# Smooth round: 13
# --> Time elapsed: 12.813283443450928
# --> Orignal sparsity=0.7937350853977926, Thresholding
# --> Final sparsity=0.6037475222340863
# similarity matrix truncated (Smooth round=13):  2.086397171020508
# Smooth round: 14
# --> Time elapsed: 13.419806003570557
# --> Orignal sparsity=0.8195896166622774, Thresholding
# --> Final sparsity=0.6386823382643301
# similarity matrix truncated (Smooth round=14):  2.068659543991089
# Smooth round: 15
# --> Time elapsed: 13.940863132476807
# --> Orignal sparsity=0.8419925873543598, Thresholding
# --> Final sparsity=0.6706816891845759
# similarity matrix truncated (Smooth round=15):  2.0459558963775635
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-2): 0.16058394160583941
# --> Clonal cell fraction (day 2-0): 0.17816354499771586
# --> Numer of cells that are clonally related -- day 0: 528  and day 2: 1170
# Number of multi-time clones post selection: 81
# Cell number=9855, Clone number=81
# --> clonal_cell_id_t1: 528
# --> Tmap_cell_id_t1: 3288
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.006311655044555664
# --> Time elapsed:  0.10820484161376953
# --> Time elapsed:  0.040170907974243164
# --> Time elapsed:  0.11577701568603516
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.005879402160644531
# --> Time elapsed:  0.10098505020141602
# --> Time elapsed:  0.03829693794250488
# --> Time elapsed:  0.12268853187561035
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.005022764205932617
# --> Time elapsed:  0.05577683448791504
# --> Time elapsed:  0.02870321273803711
# --> Time elapsed:  0.07631373405456543
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.004125118255615234
# --> Phase II: time elapsed --  0.006354331970214844
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.00406646728515625
# ...
# --> Orignal sparsity=0.44981876737636967, Thresholding
# --> Final sparsity=0.2630086053722442
# similarity matrix truncated (Smooth round=6):  2.0501224994659424
# Smooth round: 7
# --> Time elapsed: 7.310727596282959
# --> Orignal sparsity=0.5215356419431395, Thresholding
# --> Final sparsity=0.3217560750065633
# similarity matrix truncated (Smooth round=7):  2.0891876220703125
# Smooth round: 8
# --> Time elapsed: 8.48205018043518
# --> Orignal sparsity=0.585094011204661, Thresholding
# --> Final sparsity=0.3777265103041617
# similarity matrix truncated (Smooth round=8):  2.111161708831787
# Smooth round: 9
# --> Time elapsed: 9.562822818756104
# --> Orignal sparsity=0.6402611457865626, Thresholding
# --> Final sparsity=0.43029325791010237
# similarity matrix truncated (Smooth round=9):  2.1127281188964844
# Smooth round: 10
# --> Time elapsed: 10.546705961227417
# --> Orignal sparsity=0.687911185638608, Thresholding
# --> Final sparsity=0.47912752695264466
# similarity matrix truncated (Smooth round=10):  2.0626518726348877
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 16.860639810562134
# --> Orignal sparsity=0.7287457141885879, Thresholding
# --> Final sparsity=0.5242171776160156
# similarity matrix truncated (Smooth round=11):  2.1020798683166504
# Smooth round: 12
# --> Time elapsed: 17.516128063201904
# --> Orignal sparsity=0.7637607362839907, Thresholding
# --> Final sparsity=0.5656756277191923
# similarity matrix truncated (Smooth round=12):  2.3608527183532715
# Smooth round: 13
# --> Time elapsed: 17.275800704956055
# --> Orignal sparsity=0.7937350853977926, Thresholding
# --> Final sparsity=0.6037475222340863
# similarity matrix truncated (Smooth round=13):  2.0907044410705566
# Smooth round: 14
# --> Time elapsed: 18.29503059387207
# --> Orignal sparsity=0.8195896166622774, Thresholding
# --> Final sparsity=0.6386823382643301
# similarity matrix truncated (Smooth round=14):  2.0422403812408447
# Smooth round: 15
# --> Time elapsed: 18.775169134140015
# --> Orignal sparsity=0.8419925873543598, Thresholding
# --> Final sparsity=0.6706816891845759
# similarity matrix truncated (Smooth round=15):  2.0023069381713867
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-2): 0.30869829683698297
# --> Clonal cell fraction (day 2-0): 0.42332876503730776
# --> Numer of cells that are clonally related -- day 0: 1015  and day 2: 2780
# Number of multi-time clones post selection: 89
# Cell number=9855, Clone number=89
# --> clonal_cell_id_t1: 1015
# --> Tmap_cell_id_t1: 3288
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.015329122543334961
# --> Time elapsed:  0.25213146209716797
# --> Time elapsed:  0.1287534236907959
# --> Time elapsed:  0.39323878288269043
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.01398324966430664
# --> Time elapsed:  0.1693727970123291
# --> Time elapsed:  0.04593086242675781
# --> Time elapsed:  0.2044830322265625
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.013812541961669922
# --> Time elapsed:  0.1018517017364502
# --> Time elapsed:  0.04133868217468262
# --> Time elapsed:  0.12561559677124023
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.20155715942382812
# --> Phase II: time elapsed --  0.20821261405944824
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.04662752151489258
# --> Phase II: time elapsed --  0.05333089828491211
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.03389906883239746
# --> Phase II: time elapsed --  0.0409696102142334
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.025732994079589844
# --> Phase II: time elapsed --  0.0322418212890625
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.10588502883911133
# --> Phase II: time elapsed --  0.14273715019226074
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-2): 0.38453733766233766
# --> Clonal cell fraction (day 2-1): 0.4569818790924319
# --> Numer of cells that are clonally related -- day 1: 1895  and day 2: 3001
# Number of multi-time clones post selection: 112
# Cell number=11495, Clone number=112
# --> clonal_cell_id_t1: 1895
# --> Tmap_cell_id_t1: 4928
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.1478900909423828
# --> Time elapsed:  0.4613931179046631
# --> Time elapsed:  0.4260392189025879
# --> Time elapsed:  0.5472760200500488
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.11627078056335449
# --> Time elapsed:  0.39273953437805176
# --> Time elapsed:  0.3370687961578369
# --> Time elapsed:  0.45029282569885254
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.049497365951538086
# --> Time elapsed:  0.18915271759033203
# --> Time elapsed:  0.1559891700744629
# --> Time elapsed:  0.1752004623413086
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.5941088199615479
# --> Phase II: time elapsed --  0.6098873615264893
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.1442415714263916
# --> Phase II: time elapsed --  0.16260933876037598
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.09790492057800293
# --> Phase II: time elapsed --  0.11366391181945801
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.07221460342407227
# --> Phase II: time elapsed --  0.09037232398986816
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.17709779739379883
# --> Phase II: time elapsed --  0.25827980041503906
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 395.1233723163605 s ------------
# Results saved at adata.obs['fate_map_transition_map_Reprogrammed']
# Results saved at adata.obs['fate_map_transition_map_Failed']
# Results saved at adata.obs['fate_bias_transition_map_Reprogrammed*Failed']
# Time points with clonal info: ['0' '1' '2']
# WARNING: Default ascending order of time points are: ['0' '1' '2']. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.
# ------Compute the full Similarity matrix if necessary------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.0245513916015625
# Smooth round: 2
# --> Time elapsed: 0.18756651878356934
# Smooth round: 3
# --> Time elapsed: 1.3766016960144043
# --> Orignal sparsity=0.13952742364935591, Thresholding
# --> Final sparsity=0.08274391355144298
# similarity matrix truncated (Smooth round=3):  1.7449188232421875
# Smooth round: 4
# --> Time elapsed: 3.126779794692993
# --> Orignal sparsity=0.27102499292465637, Thresholding
# --> Final sparsity=0.14234637306805162
# similarity matrix truncated (Smooth round=4):  1.8642528057098389
# Smooth round: 5
# --> Time elapsed: 4.651448488235474
# --> Orignal sparsity=0.3675729065833763, Thresholding
# --> Final sparsity=0.2031454486885748
# similarity matrix truncated (Smooth round=5):  1.9422967433929443
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 22.068336009979248
# --> Orignal sparsity=0.44981876737636967, Thresholding
# --> Final sparsity=0.2630086053722442
# similarity matrix truncated (Smooth round=6):  2.0350863933563232
# Smooth round: 7
# --> Time elapsed: 32.303455114364624
# --> Orignal sparsity=0.5215356419431395, Thresholding
# --> Final sparsity=0.3217560750065633
# similarity matrix truncated (Smooth round=7):  3.7865898609161377
# Smooth round: 8
# --> Time elapsed: 55.93489146232605
# --> Orignal sparsity=0.585094011204661, Thresholding
# --> Final sparsity=0.3777265103041617
# similarity matrix truncated (Smooth round=8):  3.9759511947631836
# Smooth round: 9
# --> Time elapsed: 23.577564239501953
# --> Orignal sparsity=0.6402611457865626, Thresholding
# --> Final sparsity=0.43029325791010237
# similarity matrix truncated (Smooth round=9):  2.0430960655212402
# Smooth round: 10
# --> Time elapsed: 10.498862266540527
# --> Orignal sparsity=0.687911185638608, Thresholding
# --> Final sparsity=0.47912752695264466
# similarity matrix truncated (Smooth round=10):  2.036259412765503
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 11.364979028701782
# --> Orignal sparsity=0.7287457141885879, Thresholding
# --> Final sparsity=0.5242171776160156
# similarity matrix truncated (Smooth round=11):  2.0475070476531982
# Smooth round: 12
# --> Time elapsed: 12.240159273147583
# --> Orignal sparsity=0.7637607362839907, Thresholding
# --> Final sparsity=0.5656756277191923
# similarity matrix truncated (Smooth round=12):  2.029916763305664
# Smooth round: 13
# --> Time elapsed: 13.038440942764282
# --> Orignal sparsity=0.7937350853977926, Thresholding
# --> Final sparsity=0.6037475222340863
# similarity matrix truncated (Smooth round=13):  2.0027318000793457
# Smooth round: 14
# --> Time elapsed: 13.684428930282593
# --> Orignal sparsity=0.8195896166622774, Thresholding
# --> Final sparsity=0.6386823382643301
# similarity matrix truncated (Smooth round=14):  1.9955124855041504
# Smooth round: 15
# --> Time elapsed: 14.458395957946777
# --> Orignal sparsity=0.8419925873543598, Thresholding
# --> Final sparsity=0.6706816891845759
# similarity matrix truncated (Smooth round=15):  1.9868178367614746
# --> Save the matrix at every 5 rounds
# ------Infer transition map between initial time points and the later time one------
# --------Current initial time point: 0--------
# Step 1: Select time points
# --> Clonal cell fraction (day 0-2): 0.33728710462287104
# --> Clonal cell fraction (day 2-0): 0.5171311100959343
# --> Numer of cells that are clonally related -- day 0: 1109  and day 2: 3396
# Number of multi-time clones post selection: 96
# Cell number=9855, Clone number=96
# --> clonal_cell_id_t1: 1109
# --> Tmap_cell_id_t1: 3288
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.014975786209106445
# --> Time elapsed:  0.19667339324951172
# --> Time elapsed:  0.05558013916015625
# --> Time elapsed:  0.25422024726867676
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.014987945556640625
# --> Time elapsed:  0.20755505561828613
# --> Time elapsed:  0.04620766639709473
# --> Time elapsed:  0.23146343231201172
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.014107465744018555
# --> Time elapsed:  0.12609243392944336
# --> Time elapsed:  0.04394268989562988
# --> Time elapsed:  0.1506791114807129
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.29340267181396484
# --> Phase II: time elapsed --  0.30281758308410645
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.06288814544677734
# --> Phase II: time elapsed --  0.07131552696228027
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.04437899589538574
# --> Phase II: time elapsed --  0.05253100395202637
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.03398275375366211
# --> Phase II: time elapsed --  0.04345130920410156
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.10396981239318848
# --> Phase II: time elapsed --  0.1424560546875
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --------Current initial time point: 1--------
# Step 1: Select time points
# --> Clonal cell fraction (day 1-2): 0.5202922077922078
# --> Clonal cell fraction (day 2-1): 0.5448454393178012
# --> Numer of cells that are clonally related -- day 1: 2564  and day 2: 3578
# Number of multi-time clones post selection: 126
# Cell number=11495, Clone number=126
# --> clonal_cell_id_t1: 2564
# --> Tmap_cell_id_t1: 4928
# Step 2: Optimize the transition map recursively
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.09227395057678223
# --> Time elapsed:  0.3389883041381836
# --> Time elapsed:  0.17535710334777832
# --> Time elapsed:  0.3715822696685791
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.08419537544250488
# --> Time elapsed:  0.2985532283782959
# --> Time elapsed:  0.1566932201385498
# --> Time elapsed:  0.3254666328430176
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.054706573486328125
# --> Time elapsed:  0.15987443923950195
# --> Time elapsed:  0.10149955749511719
# --> Time elapsed:  0.18461322784423828
# Iteration 1, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  2.046306848526001
# --> Phase II: time elapsed --  2.0838675498962402
# Iteration 2, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.4267919063568115
# --> Phase II: time elapsed --  0.46324849128723145
# Iteration 3, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.24400615692138672
# --> Phase II: time elapsed --  0.28130149841308594
# Iteration 4, Use smooth_round=5
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.1256392002105713
# --> Phase II: time elapsed --  0.16274380683898926
# --> Final round of Smooth (to expand the state space of Tmap to include non-clonal states)
# --> Phase I: time elapsed --  0.28673815727233887
# --> Phase II: time elapsed --  0.3872990608215332
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 500.79128861427307 s ------------
# Results saved at adata.obs['fate_map_transition_map_Reprogrammed']
# Results saved at adata.obs['fate_map_transition_map_Failed']
# Results saved at adata.obs['fate_bias_transition_map_Reprogrammed*Failed']

# %%
cospar_dfs = []
for e in range(10):
    cospar_dfs.append(pd.read_csv('../pygot_data/03_cellfate/reprogram/cospar_{}.csv'.format(e),index_col=0))

# %% [markdown]
# ### WOT

# %%
import wot
for e in [1e-1, 5e-1, 1e-2, 5e-2, 2e-2, 3e-2, 5e-3]:
    ot_model = wot.ot.OTModel(adata, epsilon = e, lambda1 = 50, lambda2 = 1, growth_iters = 1, day_field=time_key,) 
    ot_model.compute_all_transport_maps(tmap_out='../pygot_data/03_cellfate/reprogram/serum_{}'.format(e))
# Out:
# 2025-02-25 14:46:36,966 - INFO - Computing transport map from 0 to 1
# 2025-02-25 14:46:53,441 - INFO - Computing transport map from 1 to 2
# 2025-02-25 14:47:23,851 - INFO - Computing transport map from 0 to 1
# 2025-02-25 14:47:38,301 - INFO - Computing transport map from 1 to 2
# 2025-02-25 14:48:14,081 - INFO - Computing transport map from 0 to 1
# 2025-02-25 14:49:09,663 - INFO - Computing transport map from 1 to 2

# %%
def get_wot_fate(tmap_model):
    t226 = tmap_model.get_coupling(t0=0, t1=2, covariate=None)
    t426 = tmap_model.get_coupling(t0=1, t1=2, covariate=None)
    def row_normalizing(X):
        return X / np.sum(X, axis=1)[:,None]
    
    
    
    def calcu_fate(chain, start_index):
        
        P0 = chain @ (adata.obs[adata.obs[time_key]==2][cell_type_key] == 'Failed').astype(int).to_numpy()
        P1 = chain @ (adata.obs[adata.obs[time_key]==2][cell_type_key] == 'Reprogrammed').astype(int).to_numpy()
        P2 = chain @ (adata.obs[adata.obs[time_key]==2][cell_type_key] == 'Others').astype(int).to_numpy()
        
        return pd.DataFrame([P0, P1, P2], columns=start_index, index=['Failed','Reprogrammed','Others' ]).T
    
    
    fate1 = calcu_fate(t226.X, t226.obs.index)
    fate2 = calcu_fate(t426.X, t426.obs.index)
    return pd.concat([fate1, fate2])

# %%
import wot
wot_dfs = []
for e in [1e-1, 5e-1, 1e-2, 5e-2, 2e-2, 3e-2, 5e-3]:
    tmap_model = wot.tmap.TransportMapModel.from_directory('../pygot_data/03_cellfate/reprogram/serum_pc30_{}'.format(e))
    wot_dfs.append(get_wot_fate(tmap_model))

# %% [markdown]
# ## Moscot

# %%
## run with [benchmark]03_cell_fate_reprogramming_run_moscot.py

# %%
moscot_dfs = []
for e in [1e-1, 5e-1, 1e-2, 5e-2, 1e-3, 5e-3, 1e-4]:
    moscot_dfs.append(pd.read_csv('../pygot_data/03_cellfate/reprogram/moscot_v4.0_{}.csv'.format(e),index_col=0))

# %% [markdown]
# ## Cell fate computation

# %%
got_dfs = []
for got in gots:
    adata.obsm[velocity_key] = pygot.tl.traj.latent_velocity(adata, got, embedding_key=embedding_key, time_key=time_key)
    cellfate = pygot.tl.analysis.CellFate()
    cellfate.fit(adata, embedding_key=embedding_key, velocity_key=velocity_key, cell_type_key=cell_type_key,
                 sde=True, D=1.,
                 target_cell_types=['Reprogrammed', 'Failed'], mutual=False)
    adata.obs['got_fate_bias'] = hf.get_fate_bias(adata.obsm['descendant'],['Reprogrammed', 'Failed'] )
    got_dfs.append(adata.obs.copy())
# Out:
# 2025-03-27 22:31:14 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:31:14 	 Compute transition between 0 and 1
# 2025-03-27 22:31:14 	 Compute velocity graph
# Scale factor: 16.83202190394941
# Scale factor: 16.83202190394941
# 2025-03-27 22:31:44 	 Convert into markov chain
# 2025-03-27 22:31:44 	 Solve abosorbing probabilities
# 2025-03-27 22:31:45 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:31:45 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:31:45 	 Compute transition between 0 and 1
# 2025-03-27 22:31:45 	 Compute velocity graph
# Scale factor: 17.924989272876857
# Scale factor: 17.924989272876857
# 2025-03-27 22:31:53 	 Convert into markov chain
# 2025-03-27 22:31:53 	 Solve abosorbing probabilities
# 2025-03-27 22:31:53 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:31:54 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:31:54 	 Compute transition between 0 and 1
# 2025-03-27 22:31:54 	 Compute velocity graph
# Scale factor: 16.848584847040083
# Scale factor: 16.848584847040083
# 2025-03-27 22:32:02 	 Convert into markov chain
# 2025-03-27 22:32:02 	 Solve abosorbing probabilities
# 2025-03-27 22:32:03 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:32:03 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:32:03 	 Compute transition between 0 and 1
# 2025-03-27 22:32:03 	 Compute velocity graph
# Scale factor: 17.05008352290135
# Scale factor: 17.05008352290135
# 2025-03-27 22:32:11 	 Convert into markov chain
# 2025-03-27 22:32:11 	 Solve abosorbing probabilities
# 2025-03-27 22:32:11 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:32:11 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:32:11 	 Compute transition between 0 and 1
# 2025-03-27 22:32:11 	 Compute velocity graph
# Scale factor: 18.33703099072712
# Scale factor: 18.33703099072712
# 2025-03-27 22:32:19 	 Convert into markov chain
# 2025-03-27 22:32:19 	 Solve abosorbing probabilities
# 2025-03-27 22:32:19 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:32:19 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:32:19 	 Compute transition between 0 and 1
# 2025-03-27 22:32:20 	 Compute velocity graph
# Scale factor: 17.741800518337854
# Scale factor: 17.741800518337854
# 2025-03-27 22:32:28 	 Convert into markov chain
# 2025-03-27 22:32:28 	 Solve abosorbing probabilities
# 2025-03-27 22:32:28 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:32:28 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:32:28 	 Compute transition between 0 and 1
# 2025-03-27 22:32:29 	 Compute velocity graph
# Scale factor: 17.338820791843624
# Scale factor: 17.338820791843624
# 2025-03-27 22:32:37 	 Convert into markov chain
# 2025-03-27 22:32:37 	 Solve abosorbing probabilities
# 2025-03-27 22:32:37 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:32:37 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:32:37 	 Compute transition between 0 and 1
# 2025-03-27 22:32:38 	 Compute velocity graph
# Scale factor: 17.866968812213422
# Scale factor: 17.866968812213422
# 2025-03-27 22:32:46 	 Convert into markov chain
# 2025-03-27 22:32:46 	 Solve abosorbing probabilities
# 2025-03-27 22:32:46 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:32:46 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:32:46 	 Compute transition between 0 and 1
# 2025-03-27 22:32:47 	 Compute velocity graph
# Scale factor: 17.237796953462766
# Scale factor: 17.237796953462766
# 2025-03-27 22:32:55 	 Convert into markov chain
# 2025-03-27 22:32:55 	 Solve abosorbing probabilities
# 2025-03-27 22:32:55 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']
# 2025-03-27 22:32:55 	 Compute transition roadmap among [0 1]
# 2025-03-27 22:32:55 	 Compute transition between 0 and 1
# 2025-03-27 22:32:55 	 Compute velocity graph
# Scale factor: 17.211041042875927
# Scale factor: 17.211041042875927
# 2025-03-27 22:33:03 	 Convert into markov chain
# 2025-03-27 22:33:03 	 Solve abosorbing probabilities
# 2025-03-27 22:33:03 	 Generate NULL distribution
# Export result into adata.obsm['descendant'] and adata.obsm['ancestor']

# %%
#GOT
pred_bias_gots = [df.loc[x0_adata.obs.index]['got_fate_bias'].to_numpy() for df in got_dfs]

#WOT
pred_bias_wot = [df.loc[x0_adata.obs.index].apply(lambda x: x['Reprogrammed'] / (x['Reprogrammed'] + x['Failed']), axis=1 ).to_numpy() for df in wot_dfs] 


#MOSCOT
pred_bias_moscot = [df.loc[x0_adata.obs.index.to_series().astype(int)]['moscot_fate_bias'].to_numpy() for df in moscot_dfs]

#Cospar
pred_bias_cospars = [df.loc[x0_adata.obs.index.to_series().astype(int)]['fate_bias_transition_map_Reprogrammed*Failed'].to_numpy() for df in cospar_dfs]
#    pred_bias_cospars.append(pd.read_csv('./benchmark_model/Cospar/03_cell_fate/reprogramming_fate/cospar_{}.csv'.format(i), index_col=0).loc[x0_adata.obs.index.to_series().astype(int)]['fate_bias_transition_map_Reprogrammed*Failed'].to_numpy())

# %% [markdown]
# ## Benchmarking

# %%
gots_res = [hf.correlation_2x2(pred_bias_gots[i], x0_adata, fate_bias_key=groundtruth_key, embedding_key=embedding_key).to_numpy() for i in range(len(pred_bias_gots))]
wot_res = [hf.correlation_2x2(pred_bias_wot[i],  x0_adata, fate_bias_key=groundtruth_key, embedding_key=embedding_key).to_numpy() for i in range(len(pred_bias_wot))]
moscot_res = [hf.correlation_2x2(pred_bias_moscot[i],  x0_adata, fate_bias_key=groundtruth_key, embedding_key=embedding_key).to_numpy() for i in range(len(pred_bias_moscot))]
cospar_res = [hf.correlation_2x2(pred_bias_cospars[i], x0_adata, fate_bias_key=groundtruth_key, embedding_key=embedding_key).to_numpy() for i in range(len(pred_bias_cospars))]

# %%
pcc_df =  pd.DataFrame([np.concatenate([
            np.array(gots_res)[:,1,0],
            np.array(moscot_res)[:,1,0],
            np.array(cospar_res)[:,1,0],
            np.array(wot_res)[:,1,0],
            #np.array(cfms_res)[:,-1,0], 
            #np.array(mioflows_res)[:,-1,0],
            ]), ['GOT']*len(gots_res)  + ["Moscot"]*len(moscot_res) + ["Cospar\n(with clone)"]*len(cospar_res) + ['WOT']*len(wot_res)  
                       # + ['OT-CFM']*len(wot_res) + ['MIOFlow']*len(mioflows_res) 
                       ], index=['PCC', 'Method']).T

# %%
import mplscience
mplscience.set_style(reset_current=True)
plt.rcParams['font.sans-serif'] = ['Arial']
pal=sns.color_palette()
paln=pal.copy()
paln[0]=np.array([13,111,178])/255

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.barplot(x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
            capsize=.1,  
    err_kws={"linewidth": 1.5}, order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'], 
            palette='Accent')  
sns.stripplot(x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
              color='black', alpha=.5, order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT']) 
plt.ylim(0.15, 0.6)


plt.show()

# %%
palette = {
    'GOT':'#049e74',
    'Cospar\n(with clone)':'#0066a4',
    'Moscot': '#d46126',
    'WOT':'#e5a023',
}
#palette = 'Accent'

ax = sns.barplot(
    x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
    
    capsize=.3,
    err_kws={"linewidth": 1., 'color':'grey'},
    palette=palette,
    order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'],
    #fill=False,
    legend=False,
    alpha=0.5
    
)


sns.stripplot(
    x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
    
    dodge=False,  
    jitter=0.2,  
    palette=palette, 
    alpha=1.,
    legend=False,
    #ax=ax,
    size=5,
    order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT']
)
plt.ylim(0.15, 0.6)

plt.show()

# %%
#pcc_df.to_csv('./results/03_cellfate/reprogram_res.csv')

# %%
scc, pcc, mse, r2, auc = hf.positive_control(x0_adata, embedding_key, groundtruth_key)
pcc_df = pd.concat([pcc_df, pd.DataFrame([pcc, 'supervised LR'], index=['PCC', 'Method']).T])
sns.barplot(x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
            capsize=.1, ci="sd", order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'], 
            palette='Accent')  
sns.swarmplot(x='Method', y='PCC', data=pcc_df.loc[pcc_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
              color="black", alpha=.5, order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT']) 
plt.ylim(0.15, 0.76)
plt.axhline(y=pcc_df.loc[pcc_df['Method'] == 'supervised LR']['PCC'].tolist()[0], color='red', linestyle='--', label='supervised linear regression')
plt.show()
plt.close()
# Out:
# SCC: 0.7325729433904445
# PCC: 0.7511677274567782
# Mean Squared Error: 0.06924743856156756
# R-squared: 0.5641581037874424
# ROC-AUC: 0.8757280006337049

# %% [markdown]
# ## Visulization

# %%
show_idx = (x0_adata.obsm['X_emb'][:,0]< 2) & (x0_adata.obsm['X_emb'][:,0] > -7)

# %%
import matplotlib.colors as mcolors
fig, axes = plt.subplots(1, 5, figsize=(6.4*4, 4.8))

custom_cmap='coolwarm'

norm = mcolors.TwoSlopeNorm(vmin=0., vcenter=0.5, vmax=1.)


sc.pl.embedding(x0_adata[show_idx], color=groundtruth_key, ax=axes[0], basis='emb', cmap='coolwarm', colorbar_loc=None, frameon=False, title='', show=False)

print(hf.correlation_2x2(pred_bias_gots[np.array(gots_res)[:,1,0].argsort()[len(gots_res) // 2]], x0_adata, groundtruth_key, embedding_key))
sc.pl.embedding(x0_adata[show_idx], color='pred_fate_bias', ax=axes[1], basis='emb', cmap=custom_cmap, norm=norm, colorbar_loc=None, frameon=False, title='', show=False)

print(hf.correlation_2x2(pred_bias_cospars[np.array(cospar_res)[:,1,0].argsort()[len(cospar_res) // 2]], x0_adata, groundtruth_key, embedding_key))
sc.pl.embedding(x0_adata[show_idx], color='pred_fate_bias', ax=axes[2], basis='emb', cmap=custom_cmap, norm=norm, colorbar_loc=None, frameon=False, title='', show=False)

print(hf.correlation_2x2(pred_bias_moscot[np.array(moscot_res)[:,1,0].argsort()[-3]], x0_adata, groundtruth_key, embedding_key))
sc.pl.embedding(x0_adata[show_idx], color='pred_fate_bias', ax=axes[3], basis='emb', cmap=custom_cmap, norm=norm, colorbar_loc=None, frameon=False, title='', show=False)

print(hf.correlation_2x2(pred_bias_wot[np.array(wot_res)[:,1,0].argsort()[-3]], x0_adata, groundtruth_key, embedding_key))
sc.pl.embedding(x0_adata[show_idx], color='pred_fate_bias', ax=axes[4], basis='emb', cmap=custom_cmap, norm=norm, colorbar_loc=None, frameon=False, title='', show=False)
#plt.show()
plt.savefig('/disk/share/xuruihong/pygot_fig/benchmark_cell_fate_reprogram_example.jpg', format='jpg', dpi=300)
# Out:
#      pred vs gt  sm pred vs gt  pred vs sm gt  sm pred vs sm gt
# scc    0.446090       0.449794       0.540475          0.554741
# pcc    0.548687       0.553311       0.642252          0.660236
# mse    0.137102       0.134615       0.095523          0.090888
# r2    -1.018956      -1.130812      -0.406668         -0.438666
# auc    0.804857       0.806950       0.822993          0.831659
#      pred vs gt  sm pred vs gt  pred vs sm gt  sm pred vs sm gt
# scc    0.459430       0.457587       0.563101          0.568309
# pcc    0.474853       0.471115       0.557521          0.562707
# mse    0.196183       0.198374       0.153549          0.153819
# r2    -0.990103      -1.195334      -0.557619         -0.702267
# auc    0.807669       0.806631       0.848163          0.849994
#      pred vs gt  sm pred vs gt  pred vs sm gt  sm pred vs sm gt
# scc    0.401858       0.405658       0.489655          0.501248
# pcc    0.419887       0.420161       0.490569          0.497431
# mse    0.206352       0.199849       0.164379          0.156050
# r2    -0.127954      -0.179829       0.101474          0.078746
# auc    0.785422       0.787760       0.794445          0.803170
#      pred vs gt  sm pred vs gt  pred vs sm gt  sm pred vs sm gt
# scc    0.254520       0.342603       0.332250          0.426777
# pcc    0.330260       0.427959       0.400252          0.506490
# mse    0.184516       0.139502       0.139865          0.096976
# r2    -0.659483      -1.063410      -0.257910         -0.434388
# auc    0.691436       0.752262       0.714769          0.770953

# %%
def ent(x):
    return -np.sum(np.log(x[(x>0.05)&(x<0.95)])*x[(x>0.05)&(x<0.95)]) / len(x)
    
ent_df =  pd.DataFrame([np.concatenate([
            [ent(x) for x in pred_bias_gots],
            [ent(x) for x in pred_bias_moscot],
            [ent(x) for x in pred_bias_cospars],
            [ent(x) for x in pred_bias_wot],
            
            ]), ['GOT']*len(gots_res)  + ["Moscot"]*len(moscot_res) + ["Cospar\n(with clone)"]*len(cospar_res) + ['WOT']*len(wot_res)  
                       # + ['OT-CFM']*len(wot_res) + ['MIOFlow']*len(mioflows_res) 
                       ], index=['ENT', 'Method']).T


palette = {
    'GOT':'#049e74',
    'Cospar\n(with clone)':'#0066a4',
    'Moscot': '#d46126',
    'WOT':'#e5a023',
}
#palette = 'Accent'
# 先画条形图
ax = sns.barplot(
    x='Method', y='ENT', data=ent_df.loc[ent_df['Method'].isin(['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'])], 
    
    capsize=.3,
    errorbar=None,
    err_kws={"linewidth": 1., 'color':'grey'},
    palette=palette,
    order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'],
    #fill=False,
    legend=False,
    alpha=0.5
    
)




plt.show()

# %%
ent_df.to_csv('./results/03_cellfate/reprogram_ent.csv')

# %%
ent_df1, ent_df2, ent_df3 = pd.read_csv('./results/03_cellfate/reprogram_ent.csv'), pd.read_csv('./results/03_cellfate/hpsc_ent.csv'), pd.read_csv('./results/03_cellfate/cancer_ent.csv')
ent_df1['Dataset'] = 'Reprograme'
ent_df2['Dataset'] = 'HPSC'
ent_df3['Dataset'] = 'Cycling-Cancer'

# %%
#Predicted Entropy of all datasets
palette = 'Accent'

ax = sns.barplot(
    x='Method', y='ENT', data=pd.concat([ent_df1, ent_df2, ent_df3]), 
    hue='Dataset',
    capsize=.3,
    errorbar=None,
    err_kws={"linewidth": 1., 'color':'grey'},
    palette=palette,
    order=['GOT', 'Cospar\n(with clone)', 'Moscot', 'WOT'],
    #fill=False,
    legend=False,    
)

plt.show()

# %%
# Supervised performance of all datasets
sns.barplot(pd.DataFrame([
    [0.75, 0.63, 0.41],
    ['Reprogram', 'HPSC', 'Cycling Caner']], index=['R', 'Dataset']).T,
    x='Dataset', y='R',
    palette = 'Accent'
)
plt.ylim(0.35, 0.78)
